# %% [markdown]
# ## Instacart - Clustering
# In this notebook I will try creating customer segmentation for Instacart customers according to the purchases made.  Instacart has access to thousands of products, categorized into aisles and departments.  With the large number of features, we will look at using Principal Component Analysis to find new dimensions to make clustering easier.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import seaborn as sns
sns.set(style='whitegrid')

import random

# %%
aisles = pd.read_csv('../data/raw/aisles.csv')
orders = pd.read_csv('../data/raw/orders.csv')
products = pd.read_csv('../data/raw/products.csv')
order_details_prior = pd.read_csv('../data/raw/order_products__prior.csv')
#order_details_train = pd.read_csv('../data/raw/order_products__train.csv')

# %%
len(orders.user_id.unique())
# Out:
# 206209

# %% [markdown]
# We have over 200,000 users in our order history.  This is just too much data for my laptop to crunch.  We will subset this to 15,005 users - 15,000 users will be used to train our model, with 5 users withheld to used for testing purposes.  The decrease in data will allow us to efficiently process data in a timely fashion.

# %%
# create a set of users
unique_users = set(orders.user_id.unique())

# randomly sample 15,005 users
selected_users = random.sample(unique_users, 15005)

# reduce the orders dataset to only include data from our selected users
orders_sub = orders[orders.user_id.isin(selected_users)]

# %% [markdown]
# We want to join several datasets in order to achieve an overall picture of products purchased.
#
# We will join orders, order_details_prior, products and aisles to create our master dataset.

# %%
# expand products table
products_temp = pd.merge(products, aisles, on=['aisle_id'])

# expand order details table
order_details_temp = pd.merge(order_details_prior, products_temp, on=['product_id'])

# %%
# create full purchase history
purchase_history = pd.merge(orders_sub, order_details_temp, on=['order_id'])[['user_id', 'product_id', 'product_name', 'aisle_id', 'aisle']]

# %%
# how many unique aisles do we have? 
len(purchase_history.aisle.unique())
# Out:
# 134

# %%
# how many unique products do we have?
len(purchase_history.product_id.unique())
# Out:
# 38751

# %% [markdown]
# We want to create a frequency table to identify how many products each customer has purchased.  If we to break this table down by product, we would create a 15,000 x 38,751.  The dimensions of this matrix are just too massive to be able to crunch on my laptop.
#
# Another way we can analyze this data is by aggregating it by aisle.  Doing so will us a 15,000 x 134 matrix - a much more managable dataset.  In order to create this frequency table we will used the pandas crosstab function.

# %%
ph_crosstab_full = pd.crosstab(index=purchase_history.user_id, columns=purchase_history.aisle)

# %%
# split our dataset
ph_crosstab_test = ph_crosstab_full[-5:]
ph_crosstab = ph_crosstab_full[:-5]

# %%
ph_crosstab.shape
# Out:
# (15000, 134)

# %%
ph_crosstab_test.shape
# Out:
# (5, 134)

# %% [markdown]
# We now have a summarized purchase history crosstab for our selected users.  Prior to performing a cluster analysis, we want to run a dimensionality reduction on the data to reduce our features from 134.

# %% [markdown]
# # Dimensionality Reduction
# Dimensionality reduction will be completed using Principal Component Analysis (PCA).  The aim here is to reduce the number of features while retaining the greatest explained varaince as possible.

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import Pipeline

# %% [markdown]
# We first create a PCA against all components.  This will allow us to review the explained variance and select an appropriate number of components to reduce overall dimensions.  We will also scale the data using RobustScaler.  The reason we selected RobustScaler is because our features are not normally distributed and contain many outliers.  StandardScaler is optimal for when features are normally distributed, and MinMaxScaler perfrom best without outliers.  Thus - RobustScaler.

# %%
# create pipeline
dim_pipe = Pipeline([('scaler', RobustScaler()),
            ('pca', PCA())])

# %%
# fit the dataset
dim_pipe.fit(ph_crosstab)
# Out:
# Pipeline(memory=None,
#      steps=[('scaler', RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True)), ('pca', PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False))])

# %% [markdown]
# With the PCA fit complete, we can investigate the results

# %%
# Create a plot to display explained variance
y = dim_pipe.named_steps['pca'].explained_variance_ratio_.cumsum()
x = np.arange(len(y))

# create plot
fig, ax = plt.subplots(figsize=(10, 6))

# plot
plt.bar(x, y)

# set labels
plt.xlabel('No of. Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA Explained Variance for Instacart Purchase History')
plt.yticks(np.arange(0, 1, 0.1))

fig.savefig('../reports/figures/pca_explained_variance.png')

plt.show()

# %%
# find cumulative sum of explained variance
ev_cumsum = dim_pipe.named_steps['pca'].explained_variance_ratio_.cumsum()

# find out how many components we need to expain different levels of variance
for i in np.arange(0.5, 0.9, 0.05):
    print('{0:.2f}: {1:}'.format(i, np.sum(ev_cumsum <= i)))
    
for i in np.arange(0.9, 1.01, 0.01):
    print('{0:.2f}: {1:}'.format(i, np.sum(ev_cumsum <= i)))
# Out:
# 0.50: 6
# 0.55: 9
# 0.60: 11
# 0.65: 15
# 0.70: 19
# 0.75: 25
# 0.80: 32
# 0.85: 41
# 0.90: 54
# 0.91: 57
# 0.92: 60
# 0.93: 64
# 0.94: 68
# 0.95: 72
# 0.96: 77
# 0.97: 84
# 0.98: 92
# 0.99: 102
# 1.00: 134

# %% [markdown]
# Examining the components, we find that we can explain 99% of the data using 102 components.  We will recreate our PCA specifying 102 components before transforming our original dataset.

# %%
# create pipeline with defined n_components for PCA
dim_pipe = Pipeline([('scaler', RobustScaler()),
            ('pca', PCA(n_components=102))])

# %%
# fit & transform the data
ph_crosstab_t = dim_pipe.fit_transform(ph_crosstab)

# %% [markdown]
# # Cluster Algoritms
# With our PCA components identified, we begin clustering algorithms.  We will look at:
# 1. KMeans
# 2. DBScan
# 3. Hierarchiacal Cluster
#
# Performance metrics for clustering algorithm will be analyzed in order to decide the appropriate number of clusters.  In particular, we will look at:
#
# ### Silhouette Coefficient
# The silhouette coefficient measures how close each point in one cluster is to points in the neighboring clusters.  This score varies from -1 to 1.   measure has a range of [-1, 1].
#
# Scores near 1 show that the samples are far away from the neighboring clusters.  scores of 0 indicate that samples overlap or are very close to the decision boundary between enighbouring clusters.  Negative values indicate that samples might have been assigned to the wrong cluster.
#
# ### Calinski-Harabaz Index
# Calinski-Harabaz compares between-cluster dispersion to the within-cluster dispersion.  The higher the score, the more dense and well separated our clusters appear to be.
#
# Once an appropriate number of clusters are identified, we then will examine the top products purchased by customers in each cluster.

# %%
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.metrics import silhouette_score, calinski_harabaz_score

# %% [markdown]
# ## 1. KMeans Clustering
#
# KMeans is fairly straight forward - however we need to determine the appropriate amount of clusters to be used for our algorithm.
#
# The below function (kmeans_performance_metrics) was created for measuring kmeans performance metrics such as inertia, silhouette score and calinski-harabaz score.  It simply takes a dataset and an upper limit of k to use for clustering.  The metrics are calculated and returned.

# %%
def kmeans_performance_metrics(data, k):
    '''
        Compute K-Means partitions for various values of K, ranging from 
        2 to k+1.  Caclucate the inertia, silhouette score, and calinkski-harabaz
        score for each value of k, returning the results.
        
        Params
        ------
        data: The dataset to perform KMeans clustering
        
        k: The number of partitions to create
    '''
    
    # create an array to hold our results
    inertias = []
    silhouette_scores = []
    calinski_score = []
    
    # Process each range
    for i in range(2, k+1):
        print('processing k={}'.format(i))
        
        # build model
        model = KMeans(n_clusters=i, init='k-means++',random_state=42).fit(data)
        
        # determine scores
        inertias.append(model.inertia_)
        silhouette_scores.append(silhouette_score(data, model.labels_))
        calinski_score.append(calinski_harabaz_score(data, model.labels_))
    
    return inertias, silhouette_scores, calinski_score

# %%
# define how many clusters we want to test
clusters=15

# find the inertias related to each cluster size
inertias, silhouette_scores, calinski_score = kmeans_performance_metrics(ph_crosstab_t, clusters)
# Out:
# processing k=2
# processing k=3
# processing k=4
# processing k=5
# processing k=6
# processing k=7
# processing k=8
# processing k=9
# processing k=10
# processing k=11
# processing k=12
# processing k=13
# processing k=14
# processing k=15

# %% [markdown]
# ### Inertia Results

# %%
# Plot our results for inertia vs cluster size
fig, ax = plt.subplots(figsize=(10,6))

# plot results
plt.plot(np.arange(2, clusters+1), inertias, 'o-', color='blue', linewidth=3)

# set labels
plt.xlabel('k [# of clusters]')
plt.ylabel('Inertia')
plt.title('Inertia vs KMean Parameter')

plt.savefig('../reports/figures/kmeans_inertia.png')

plt.show()

# %% [markdown]
# We are trying to find a balance between K and inertia - minimizing inertia within our clusters as much as possible.
#
# We see a distinct elbow at k=3, however dimishing returns could be argued to occur after k=8 or k=9.  My initial thoughts are that 9 clusters seems very high for the data, though I have no prior experience with the dataset.
#
# If we were to simply select based on a value that minimizes k, I'd want to select k = 8.  Based on this graph alone, we cannot make a decision.  Let's move onto our other performance metrics for further analysis.

# %% [markdown]
# ### Silhouette Results

# %%
# plot silhouette vs cluster size 
fig, ax = plt.subplots(figsize=(10,6))

# plot silhouette_scores
plt.plot(np.arange(2, clusters+1), silhouette_scores)

# set label
plt.ylabel('Silhouette Coefficient')
plt.xlabel('k[# of clusters]')
plt.title('Silhouette Coefficient vs KMean Parameter')

# save
plt.savefig('../reports/figures/kmeans_silhouette_coefficient.png')

plt.show()

# %% [markdown]
# Silhouette scores near 1 show that smaples are far away from neighboring clusters.  Inspecting the plot above, we are looking for values of k that maximize the Silhouette Coefficient.
#
# Silhouette scores appear to decrease signifcantly once k > 4.  It's clear that smaller values of k produce a higher silhouette coefficient.

# %% [markdown]
# ### Calinski-Harabaz Score Results

# %%
# plot calinski score vs cluster size
fig, ax = plt.subplots(figsize=(10,6))

# plot calinski_score
plt.plot(np.arange(2, clusters+1), calinski_score)

# set label
plt.ylabel('Calinski-Harabaz Score')
plt.xlabel('k[# of clusters]')
plt.title('Calinski-Harabaz Score vs KMean Parameter')

# save
plt.savefig('../reports/figures/kmeans_calinski_harabaz_score.png')

plt.show()

# %% [markdown]
# A high Calinski-Harabaz score represents dense, well separated clusters.  Based on the above graph, we are likely to select k = 2, 3, or even 4.
#
# Combining all performance metrics together, we have a decision - k =2,3, or 4 appear to all be viable selections.  Let's take a quick look at cluster sizes to see if there is any information we can gather.

# %%
kmeans_model = KMeans(n_clusters=2, init='k-means++', random_state=42).fit(ph_crosstab_t)
c_pred = kmeans_model.predict(ph_crosstab_t)

# print our the number of observations per cluster
for c in np.unique(c_pred):
        print('cluster {}: {}'.format(c, np.sum(c_pred==c)))
# Out:
# cluster 0: 1275
# cluster 1: 13725

# %%
kmeans_model = KMeans(n_clusters=3, init='k-means++', random_state=42).fit(ph_crosstab_t)
c_pred = kmeans_model.predict(ph_crosstab_t)

# print our the number of observations per cluster
for c in np.unique(c_pred):
        print('cluster {}: {}'.format(c, np.sum(c_pred==c)))
# Out:
# cluster 0: 13430
# cluster 1: 134
# cluster 2: 1436

# %%
kmeans_model = KMeans(n_clusters=4, init='k-means++', random_state=42).fit(ph_crosstab_t)
c_pred = kmeans_model.predict(ph_crosstab_t)

# print our the number of observations per cluster
for c in np.unique(c_pred):
        print('cluster {}: {}'.format(c, np.sum(c_pred==c)))
# Out:
# cluster 0: 13167
# cluster 1: 130
# cluster 2: 1621
# cluster 3: 82

# %% [markdown]
# We actually have a fairly decent distribution of cluster sizes for k=4.  Let's proceed forward with this selection to see how we do.

# %% [markdown]
# ### KMeans Clustering Results
# We will build a final model where k=4 and see what our clusters can tell us about product data.

# %%
kmeans_model = KMeans(n_clusters=4, init='k-means++', random_state=42).fit(ph_crosstab_t)
c_pred = kmeans_model.predict(ph_crosstab_t)

# add the predicticed cluster to our original dataframe
kmeans_cust = ph_crosstab.copy()
kmeans_cust['cluster'] = c_pred

# print our the number of observations per cluster
for c in np.unique(kmeans_cust.cluster):
        print('cluster {}: {}'.format(c, np.sum(kmeans_cust.cluster==c)))
# Out:
# cluster 0: 13167
# cluster 1: 130
# cluster 2: 1621
# cluster 3: 82

# %% [markdown]
# With the predictions attached to our original dataframe, gather the top 12 aisles for each cluster.

# %%
kmeans_cust.groupby('cluster').mean()
# Out:
# aisle    air fresheners candles  asian foods  baby accessories  \
# cluster
# 0                      0.082403     0.498063          0.019443
# 1                      0.176923     2.369231          0.553846
# 2                      0.281308     2.908081          0.221468
# 3                      0.170732     3.402439          0.073171
#
# aisle    baby bath body care  baby food formula  bakery desserts  \
# cluster
# 0                   0.022101           0.676388         0.114605
# 1                   0.407692          99.946154         0.630769
# 2                   0.158544           3.969155         0.611351
# 3                   0.060976           5.085366         0.292683
#
# aisle    baking ingredients  baking supplies decor    beauty  beers coolers  \
# cluster
# 0                  1.026961               0.078682  0.020961       0.170654
# 1                  5.176923               0.323077  0.061538       0.015385
# 2                  5.874769               0.381863  0.080197       0.486120
# 3                  3.682927               0.134146  0.060976       1.024390
#
# aisle      ...       spreads        tea  tofu meat alternatives  \
# cluster    ...
# 0          ...      0.832156   0.672211                0.350118
# 1          ...      6.030769   3.300000                1.723077
# 2          ...      5.421962   4.594078                2.429365
# 3          ...      8.890244  16.426829                1.963415
#
# aisle    tortillas flat bread  trail mix snack mix  trash bags liners  \
# cluster
# 0                    0.568543             0.109364           0.098808
# 1                    3.538462             0.230769           0.561538
# 2                    3.537323             0.653917           0.515114
# 3                    1.975610             1.036585           0.243902
#
# aisle    vitamins supplements  water seltzer sparkling water  white wines  \
# cluster
# 0                    0.150908                       2.742918     0.106782
# 1                    0.969231                      11.869231     0.053846
# 2                    0.843924                      12.552128     0.346700
# 3                    1.146341                      41.939024     0.024390
#
# aisle       yogurt
# cluster
# 0         4.192147
# 1        30.546154
# 2        25.552745
# 3        61.390244
#
# [4 rows x 134 columns]

# %% [markdown]
# #### Cluster 0

# %%
# find the top 12 aisles per cluster by percentage of total purchase
top_aisle_per = kmeans_cust[kmeans_cust.cluster==0].mean() / kmeans_cust[kmeans_cust.cluster==0].mean().sum()
top_aisle_per.sort_values(ascending=False)[:12]
# Out:
# aisle
# fresh fruits                     0.114574
# fresh vegetables                 0.113266
# packaged vegetables fruits       0.056516
# yogurt                           0.042561
# packaged cheese                  0.029530
# water seltzer sparkling water    0.027848
# milk                             0.026206
# chips pretzels                   0.021182
# soy lactosefree                  0.019753
# bread                            0.017500
# refrigerated                     0.017273
# frozen produce                   0.016768
# dtype: float64

# %% [markdown]
# Cluster 0 is characterized by customers who purchase primarily fresh vegetables & fresh fruits, followed by packaged vegetables/fruits and yogurt.

# %% [markdown]
# #### Cluster 1

# %%
# find the top aisle per cluster by percentage of total purchase
top_aisle_per = kmeans_cust[kmeans_cust.cluster==1].mean() / kmeans_cust[kmeans_cust.cluster==1].mean().sum()
top_aisle_per.sort_values(ascending=False)[:12]
# Out:
# aisle
# baby food formula                0.142467
# fresh fruits                     0.115471
# fresh vegetables                 0.092149
# packaged vegetables fruits       0.050526
# yogurt                           0.043542
# packaged cheese                  0.034002
# milk                             0.030768
# bread                            0.018794
# soy lactosefree                  0.018542
# chips pretzels                   0.018092
# water seltzer sparkling water    0.016919
# frozen produce                   0.016754
# dtype: float64

# %% [markdown]
# Cluster 1 is characterized primarily by customers purchasing baby food formula, fresh fruits and fresh vegetables.
#
# They are also likely to buy packaged vegetables/frutis, yogurt, packaged cheese and milk products.

# %% [markdown]
# #### Cluster 2

# %%
# find the top aisle per cluster by percentage of total purchase
top_aisle_per = kmeans_cust[kmeans_cust.cluster==2].mean() / kmeans_cust[kmeans_cust.cluster==2].mean().sum()
top_aisle_per.sort_values(ascending=False)[:12]
# Out:
# aisle
# fresh fruits                     0.109600
# fresh vegetables                 0.101086
# packaged vegetables fruits       0.052744
# yogurt                           0.045264
# packaged cheese                  0.031503
# milk                             0.028386
# chips pretzels                   0.024114
# water seltzer sparkling water    0.022235
# soy lactosefree                  0.019711
# bread                            0.018639
# refrigerated                     0.017164
# crackers                         0.015698
# dtype: float64

# %% [markdown]
# Cluster 2 is very similar to cluster 0.  They primarly buy fresh fruits & fresh vegetables, but it represents a lesser percentage of their overall purchase.  This could be because they buy a larger variety of than cluster 0.
#
# We see a larger difference between cluster 2 and 0 further down the list of top aisles:
# * Cluster 2 customers are more likely to buy milk & chip/pretzels than sparkling water.
# * Cluster 2 customers are more likely to buy crackers over frozen produce.

# %% [markdown]
# #### Cluster 3

# %%
# find the top aisle per cluster by percentage of total purchase
top_aisle_per = kmeans_cust[kmeans_cust.cluster==3].mean() / kmeans_cust[kmeans_cust.cluster==3].mean().sum()
top_aisle_per.sort_values(ascending=False)[:12]
# Out:
# aisle
# fresh fruits                     0.115085
# energy granola bars              0.107789
# yogurt                           0.073316
# fresh vegetables                 0.052897
# water seltzer sparkling water    0.050086
# packaged vegetables fruits       0.037517
# refrigerated                     0.033104
# chips pretzels                   0.030206
# packaged cheese                  0.026113
# milk                             0.025953
# soy lactosefree                  0.024045
# tea                              0.019618
# dtype: float64

# %% [markdown]
# Finally, cluster 3 is characterized by customers who primarly purchase fresh fruits and energy granola bars.
#
# They are also likely to buy yogurt, fresh vegetables * sparkling water.

# %%
#find overall top aisles for kmeans clusters
kmeans_top_aisles = set()

# get top 12 aisles for each cluster & add aisle name to top_aisles
for c in np.unique(kmeans_cust.cluster):
    for a in kmeans_cust[kmeans_cust.cluster==c].mean().sort_values(ascending=False)[:12].index.values:
        kmeans_top_aisles.add(a)
        
kmeans_top_aisles = list(kmeans_top_aisles)
kmeans_top_aisles.sort()

# %% [markdown]
# ### KMeans Clustering Predictions
# Taking our holdout dataset, where do our new customers fall into the predicted clusters?

# %%
# transform our dataset into the PCA space
ph_crosstab_test_t = dim_pipe.transform(ph_crosstab_test)

# %%
# Predict the clusters
kmeans_cust_test = ph_crosstab_test.copy()
kmeans_cust_test['cluster'] = kmeans_model.predict(ph_crosstab_test_t)

# %%
kmeans_top_aisles.append('cluster')

kmeans_cust_test[kmeans_top_aisles]
# Out:
# aisle    baby food formula  bread  chips pretzels  crackers  \
# user_id
# 206138                   0      1               1         0
# 206171                   0      0               0         5
# 206195                   0      0               0         0
# 206199                   3      6              18        15
# 206204                   0      0               0         0
#
# aisle    energy granola bars  fresh fruits  fresh vegetables  frozen produce  \
# user_id
# 206138                     0            33                 2              11
# 206171                     0             0                 0               0
# 206195                     0             6                 3               1
# 206199                     4            10                14               0
# 206204                     0             3                 6               1
#
# aisle    milk  packaged cheese  packaged vegetables fruits  refrigerated  \
# user_id
# 206138     12                2                           2             0
# 206171      0                4                           0             0
# 206195      3                3                           4             0
# 206199      5               13                           3             6
# 206204      1                1                           4             0
#
# aisle    soy lactosefree  tea  water seltzer sparkling water  yogurt  cluster
# user_id
# 206138                 0    0                              0       0        0
# 206171                 1    0                              6       0        0
# 206195                 0    0                              0       1        0
# 206199                 0    0                              5      48        2
# 206204                 2    0                              0       2        0

# %% [markdown]
# Users 1, 2, 3, 5 were placed into cluster 0, characterized by:
# * Customers primarily purchase fresh fruits, fresh vegetables
# * Customers are also likley to buy pacakged vegetables/fruits, pacakged cheese, yogurt, and milk in smaller quantities
# * Customers are likley to buy frozen produce
#
# User 4 was placed into cluster 2.  Although user 4 shares simliar qualities as those placed into cluster 0, there are key purchases that set them apart:
# * Customers are more likely to buy crackers over frozen produce
# * Customers are more likely to buy chips/pretzels

# %% [markdown]
# ## DBSCAN Clustering
# Our next clustering algorithm uses DBSCAN.  Before we begin, we need to predict two DBSCAN parameters: eps and min_smaples.  These parameters can be selected by looking at the distance to the i-th nearest neighbor, as discussed in the original DBSCAN paper by Martin Ester https://www.aaai.org/Papers/KDD/1996/KDD96-037.pdf

# %%
from scipy.spatial.distance import pdist, cdist, squareform

# %%
def kDist(data, k):
    '''
        Returns the distance between a point and it's k-th negihbors
        
        Parameters
        ----------
        data: the data used for predictions
        
        k: The number of points to find distance 
    '''
    nData = data.shape[0]
    pDistMat = squareform(pdist(data))
    kDistArray = [ sorted(pDistMat[i,:])[k-1] for i in range(nData)]

    return sorted(kDistArray, reverse=True)

# %% [markdown]
# We are going to calculate the distance along various values of 'k'.  Plotting the result to determine the appropriate eps value.  Ester states that k=4 provided decent results in the majority of cases.  We will plot k=4 with value above and below for good measure.

# %%
# calculate kdist for various values
kDistArray_2 = kDist(ph_crosstab_t, 2)
kDistArray_3 = kDist(ph_crosstab_t, 3)
kDistArray_4 = kDist(ph_crosstab_t, 4)
kDistArray_6 = kDist(ph_crosstab_t, 6)
kDistArray_8 = kDist(ph_crosstab_t, 8)
kDistArray_10 = kDist(ph_crosstab_t, 10)

# %%
fig = plt.figure(figsize=(10,6))

# plot various values of k
plt.plot(range(ph_crosstab_t.shape[0]), kDistArray_4, color='seagreen', label='4th-Dist.')
#plt.plot(range(ph_crosstab_t.shape[0]), kDistArray_6, color='lightblue', label='6th-Dist.')
#plt.plot(range(ph_crosstab_t.shape[0]), kDistArray_8, color='lightblue', label='8th-Dist.')
plt.plot(range(ph_crosstab_t.shape[0]), kDistArray_10, color='orange', label='10th-Dist.')

plt.xlabel('sorted data point index', size=14)
plt.ylabel('distance', size=14)
plt.title('Distance to the i-th nearest neighbor', size=14)
plt.legend()

fig.savefig('../reports/figures/dbscan_eps_estimator.png')

plt.show()

# %% [markdown]
# At such a zoomed out scale, it is hard to accurately select a value of eps.  We can zoom into the first segement of the graph to identify the first area that the plot begins to bend.  This allows us to select an appropriate value for further testing.

# %%
fig = plt.figure(figsize=(10,6))

# plot various values of k
plt.plot(range(ph_crosstab_t.shape[0]), kDistArray_4, color='seagreen', label='4th-Dist.')
plt.plot(range(ph_crosstab_t.shape[0]), kDistArray_10, color='orange', label='10th-Dist.')

plt.xlim([0,250])
plt.xlabel('sorted data point index', size=14)
plt.ylabel('distance', size=14)
plt.title('Distance to the i-th nearest neighbor', size=14)
plt.legend()

kDistLim = 120
plt.axhline(kDistLim, linestyle='--', c='dimgray')

fig.savefig('../reports/figures/dbscan_eps_estimator_zoom.png')

plt.show()

# %% [markdown]
# We find an elbow value at about 120 that we decide to use for our value of EPS.  Since the value is based on the 4th-nearest neighbor, we will use 4 as our starting min_samples.
#
# With the initial values selected, we can perform some fine tuning of the algorithm.  We want to minimize the number of noise points and aim for a cluster size of 3 (as we found using Kmeans).

# %%
# create a dataframe for holding our results
dbscan_results = pd.DataFrame(columns=['eps', 'min_samples', 'clusters', 'noise_pts'])

# create values for testing eps & min samples
eps_ = [60, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 90,
        91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 105, 110, 
        115, 120, 125, 126, 127, 128, 129, 130]
min_samples_ = [2, 3, 4, 5, 10]

for e in eps_:
    for m in min_samples_:
        db = DBSCAN(eps=e, min_samples=m).fit(ph_crosstab_t)

        print('eps: {}, min_samples: {}, clusters: {}, noise: {}'.format(e, m, len([i for i in np.unique(db.labels_) if i != -1]), np.sum(db.labels_ < 0)))
        
        labels = db.labels_
        n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
        noise_pts = len([1 for i in labels if i == -1])

        df_pt = pd.DataFrame({'eps':[e],
                             'min_samples':[m],
                             'clusters':[n_clusters],
                             'noise_pts': [noise_pts]})

        dbscan_results = pd.concat([dbscan_results, df_pt],axis=0)
# Out:
# eps: 60, min_samples: 2, clusters: 1, noise: 396
# eps: 60, min_samples: 3, clusters: 1, noise: 396
# eps: 60, min_samples: 4, clusters: 1, noise: 397
# eps: 60, min_samples: 5, clusters: 1, noise: 398
# eps: 60, min_samples: 10, clusters: 1, noise: 400
# eps: 70, min_samples: 2, clusters: 3, noise: 255
# eps: 70, min_samples: 3, clusters: 2, noise: 257
# eps: 70, min_samples: 4, clusters: 1, noise: 261
# eps: 70, min_samples: 5, clusters: 1, noise: 262
# eps: 70, min_samples: 10, clusters: 1, noise: 265
# eps: 71, min_samples: 2, clusters: 3, noise: 249
# eps: 71, min_samples: 3, clusters: 2, noise: 251
# eps: 71, min_samples: 4, clusters: 1, noise: 254
# eps: 71, min_samples: 5, clusters: 1, noise: 254
# eps: 71, min_samples: 10, clusters: 1, noise: 258
# eps: 72, min_samples: 2, clusters: 3, noise: 235
# eps: 72, min_samples: 3, clusters: 2, noise: 237
# eps: 72, min_samples: 4, clusters: 1, noise: 240
# eps: 72, min_samples: 5, clusters: 1, noise: 241
# eps: 72, min_samples: 10, clusters: 1, noise: 243
# eps: 73, min_samples: 2, clusters: 3, noise: 223
# eps: 73, min_samples: 3, clusters: 2, noise: 225
# eps: 73, min_samples: 4, clusters: 1, noise: 228
# eps: 73, min_samples: 5, clusters: 1, noise: 228
# eps: 73, min_samples: 10, clusters: 1, noise: 231
# eps: 74, min_samples: 2, clusters: 3, noise: 213
# eps: 74, min_samples: 3, clusters: 2, noise: 215
# eps: 74, min_samples: 4, clusters: 1, noise: 218
# eps: 74, min_samples: 5, clusters: 1, noise: 218
# eps: 74, min_samples: 10, clusters: 1, noise: 221
# eps: 75, min_samples: 2, clusters: 3, noise: 203
# eps: 75, min_samples: 3, clusters: 2, noise: 205
# eps: 75, min_samples: 4, clusters: 1, noise: 209
# eps: 75, min_samples: 5, clusters: 1, noise: 209
# eps: 75, min_samples: 10, clusters: 1, noise: 211
# eps: 76, min_samples: 2, clusters: 3, noise: 194
# eps: 76, min_samples: 3, clusters: 2, noise: 196
# eps: 76, min_samples: 4, clusters: 1, noise: 201
# eps: 76, min_samples: 5, clusters: 1, noise: 201
# eps: 76, min_samples: 10, clusters: 1, noise: 202
# eps: 77, min_samples: 2, clusters: 3, noise: 186
# eps: 77, min_samples: 3, clusters: 2, noise: 188
# eps: 77, min_samples: 4, clusters: 1, noise: 193
# eps: 77, min_samples: 5, clusters: 1, noise: 193
# eps: 77, min_samples: 10, clusters: 1, noise: 194
# eps: 78, min_samples: 2, clusters: 3, noise: 174
# eps: 78, min_samples: 3, clusters: 2, noise: 176
# eps: 78, min_samples: 4, clusters: 1, noise: 180
# eps: 78, min_samples: 5, clusters: 1, noise: 181
# eps: 78, min_samples: 10, clusters: 1, noise: 182
# eps: 79, min_samples: 2, clusters: 2, noise: 163
# eps: 79, min_samples: 3, clusters: 1, noise: 165
# eps: 79, min_samples: 4, clusters: 1, noise: 166
# eps: 79, min_samples: 5, clusters: 1, noise: 169
# eps: 79, min_samples: 10, clusters: 1, noise: 170
# eps: 80, min_samples: 2, clusters: 2, noise: 160
# eps: 80, min_samples: 3, clusters: 1, noise: 162
# eps: 80, min_samples: 4, clusters: 1, noise: 163
# eps: 80, min_samples: 5, clusters: 1, noise: 166
# eps: 80, min_samples: 10, clusters: 1, noise: 167
# eps: 90, min_samples: 2, clusters: 2, noise: 104
# eps: 90, min_samples: 3, clusters: 1, noise: 106
# eps: 90, min_samples: 4, clusters: 1, noise: 106
# eps: 90, min_samples: 5, clusters: 1, noise: 106
# eps: 90, min_samples: 10, clusters: 1, noise: 107
# eps: 91, min_samples: 2, clusters: 2, noise: 100
# eps: 91, min_samples: 3, clusters: 1, noise: 102
# eps: 91, min_samples: 4, clusters: 1, noise: 102
# eps: 91, min_samples: 5, clusters: 1, noise: 102
# eps: 91, min_samples: 10, clusters: 1, noise: 103
# eps: 92, min_samples: 2, clusters: 2, noise: 93
# eps: 92, min_samples: 3, clusters: 1, noise: 95
# eps: 92, min_samples: 4, clusters: 1, noise: 95
# eps: 92, min_samples: 5, clusters: 1, noise: 95
# eps: 92, min_samples: 10, clusters: 1, noise: 96
# eps: 93, min_samples: 2, clusters: 3, noise: 87
# eps: 93, min_samples: 3, clusters: 1, noise: 91
# eps: 93, min_samples: 4, clusters: 1, noise: 91
# eps: 93, min_samples: 5, clusters: 1, noise: 91
# eps: 93, min_samples: 10, clusters: 1, noise: 92
# eps: 94, min_samples: 2, clusters: 3, noise: 85
# eps: 94, min_samples: 3, clusters: 1, noise: 89
# eps: 94, min_samples: 4, clusters: 1, noise: 89
# eps: 94, min_samples: 5, clusters: 1, noise: 90
# eps: 94, min_samples: 10, clusters: 1, noise: 90
# eps: 95, min_samples: 2, clusters: 3, noise: 79
# eps: 95, min_samples: 3, clusters: 1, noise: 83
# eps: 95, min_samples: 4, clusters: 1, noise: 83
# eps: 95, min_samples: 5, clusters: 1, noise: 83
# eps: 95, min_samples: 10, clusters: 1, noise: 84
# eps: 96, min_samples: 2, clusters: 3, noise: 74
# eps: 96, min_samples: 3, clusters: 1, noise: 78
# eps: 96, min_samples: 4, clusters: 1, noise: 78
# eps: 96, min_samples: 5, clusters: 1, noise: 78
# eps: 96, min_samples: 10, clusters: 1, noise: 79
# eps: 97, min_samples: 2, clusters: 3, noise: 71
# eps: 97, min_samples: 3, clusters: 1, noise: 75
# eps: 97, min_samples: 4, clusters: 1, noise: 75
# eps: 97, min_samples: 5, clusters: 1, noise: 75
# eps: 97, min_samples: 10, clusters: 1, noise: 76
# eps: 98, min_samples: 2, clusters: 3, noise: 70
# eps: 98, min_samples: 3, clusters: 1, noise: 74
# eps: 98, min_samples: 4, clusters: 1, noise: 74
# eps: 98, min_samples: 5, clusters: 1, noise: 74
# eps: 98, min_samples: 10, clusters: 1, noise: 75
# eps: 99, min_samples: 2, clusters: 3, noise: 67
# eps: 99, min_samples: 3, clusters: 2, noise: 69
# eps: 99, min_samples: 4, clusters: 1, noise: 72
# eps: 99, min_samples: 5, clusters: 1, noise: 72
# eps: 99, min_samples: 10, clusters: 1, noise: 73
# eps: 100, min_samples: 2, clusters: 4, noise: 65
# eps: 100, min_samples: 3, clusters: 2, noise: 69
# eps: 100, min_samples: 4, clusters: 1, noise: 72
# eps: 100, min_samples: 5, clusters: 1, noise: 72
# eps: 100, min_samples: 10, clusters: 1, noise: 73
# eps: 105, min_samples: 2, clusters: 5, noise: 50
# eps: 105, min_samples: 3, clusters: 2, noise: 56
# eps: 105, min_samples: 4, clusters: 1, noise: 59
# eps: 105, min_samples: 5, clusters: 1, noise: 59
# eps: 105, min_samples: 10, clusters: 1, noise: 59
# eps: 110, min_samples: 2, clusters: 5, noise: 37
# eps: 110, min_samples: 3, clusters: 2, noise: 43
# eps: 110, min_samples: 4, clusters: 2, noise: 43
# eps: 110, min_samples: 5, clusters: 1, noise: 47
# eps: 110, min_samples: 10, clusters: 1, noise: 47
# eps: 115, min_samples: 2, clusters: 3, noise: 28
# eps: 115, min_samples: 3, clusters: 2, noise: 30
# eps: 115, min_samples: 4, clusters: 1, noise: 34
# eps: 115, min_samples: 5, clusters: 1, noise: 34
# eps: 115, min_samples: 10, clusters: 1, noise: 37
# eps: 120, min_samples: 2, clusters: 3, noise: 24
# eps: 120, min_samples: 3, clusters: 2, noise: 26
# eps: 120, min_samples: 4, clusters: 1, noise: 30
# eps: 120, min_samples: 5, clusters: 1, noise: 30
# eps: 120, min_samples: 10, clusters: 1, noise: 30
# eps: 125, min_samples: 2, clusters: 3, noise: 18
# eps: 125, min_samples: 3, clusters: 2, noise: 20
# eps: 125, min_samples: 4, clusters: 2, noise: 21
# eps: 125, min_samples: 5, clusters: 1, noise: 25
# eps: 125, min_samples: 10, clusters: 1, noise: 25
# eps: 126, min_samples: 2, clusters: 3, noise: 18
# eps: 126, min_samples: 3, clusters: 2, noise: 20
# eps: 126, min_samples: 4, clusters: 2, noise: 20
# eps: 126, min_samples: 5, clusters: 1, noise: 25
# eps: 126, min_samples: 10, clusters: 1, noise: 25
# eps: 127, min_samples: 2, clusters: 2, noise: 18
# eps: 127, min_samples: 3, clusters: 1, noise: 20
# eps: 127, min_samples: 4, clusters: 1, noise: 20
# eps: 127, min_samples: 5, clusters: 1, noise: 21
# eps: 127, min_samples: 10, clusters: 1, noise: 24
# eps: 128, min_samples: 2, clusters: 2, noise: 15
# eps: 128, min_samples: 3, clusters: 1, noise: 17
# eps: 128, min_samples: 4, clusters: 1, noise: 17
# eps: 128, min_samples: 5, clusters: 1, noise: 17
# eps: 128, min_samples: 10, clusters: 1, noise: 22
# eps: 129, min_samples: 2, clusters: 2, noise: 15
# eps: 129, min_samples: 3, clusters: 1, noise: 17
# eps: 129, min_samples: 4, clusters: 1, noise: 17
# eps: 129, min_samples: 5, clusters: 1, noise: 17
# eps: 129, min_samples: 10, clusters: 1, noise: 21
# eps: 130, min_samples: 2, clusters: 2, noise: 15
# eps: 130, min_samples: 3, clusters: 1, noise: 17
# eps: 130, min_samples: 4, clusters: 1, noise: 17
# eps: 130, min_samples: 5, clusters: 1, noise: 17
# eps: 130, min_samples: 10, clusters: 1, noise: 21

# %% [markdown]
# Let's take a look at the results -  We want to find an eps value that minimizes noise points for cluster sizes.  We saw in Kmeans that a cluster size of 4 worked well.  Looking at the inital results, we see that DBSCAN did not produce any cluster sizes of 4.

# %%
# create plot
fig, ax = plt.subplots(figsize=(10, 6))

# plot value for cluster size = 1
x = dbscan_results[(dbscan_results.clusters==1) & (dbscan_results.min_samples==3)].sort_values('eps').eps.values
y = dbscan_results[(dbscan_results.clusters==1) & (dbscan_results.min_samples==3)].sort_values('eps').noise_pts.values
plt.plot(x, y, label='cluster size = 1')

# plot value for cluster size = 2
x = dbscan_results[(dbscan_results.clusters==2)].sort_values('eps').eps.values
y = dbscan_results[(dbscan_results.clusters==2)].sort_values('eps').noise_pts.values
plt.plot(x, y, label='cluster size = 2')

# plot value for cluster size = 3
x = dbscan_results[(dbscan_results.clusters==3)].sort_values('eps').eps.values
y = dbscan_results[(dbscan_results.clusters==3)].sort_values('eps').noise_pts.values
plt.plot(x, y, label='cluster size = 3')

# set labels
plt.title('DBSCAN Results (min_samples=2)')
plt.xlabel('Eps')
plt.ylabel('Noise Pts')
plt.legend()

fig.savefig('../reports/figures/dbscan_eps_tuning.png')

plt.show()

# %% [markdown]
# It appears that cluster sizes 1 & 2 perform similarly with regards to noise points.  Creating an algorithm that only crates 1 or 2 clusters does not seem to be very effective for our purposes.
#
# As a result, we look to parameters that produce 3 clusters.  We can find these parameters by selecting the row where clusters = 3 as seen below:

# %%
dbscan_results[dbscan_results.clusters==3].sort_values('noise_pts').head()
# Out:
#   clusters  eps min_samples noise_pts
# 0        3  126           2        18
# 0        3  125           2        18
# 0        3  120           2        24
# 0        3  115           2        28
# 0        3   99           2        67

# %% [markdown]
# Looking at the values, they look great - we achieve 3 clusters with only 18 noise points.  However, if we actually look into the clustering sizes, we find that the the majority of points are in a single cluster.
#
# Note: (-1) cluster represents the noise points.

# %%
db_model = DBSCAN(eps=126, min_samples=2).fit(ph_crosstab_t)

dbscan_cust = ph_crosstab.copy()
dbscan_cust['cluster'] = db_model.labels_

# print our the number of observations per cluster
for c in np.unique(dbscan_cust.cluster):
        print('cluster {}: {}'.format(c, np.sum(dbscan_cust.cluster==c)))
# Out:
# cluster -1: 18
# cluster 0: 14976
# cluster 1: 4
# cluster 2: 2

# %%
db_model = DBSCAN(eps=130, min_samples=2).fit(ph_crosstab_t)

dbscan_cust = ph_crosstab.copy()
dbscan_cust['cluster'] = db_model.labels_

# print our the number of observations per cluster
for c in np.unique(dbscan_cust.cluster):
        print('cluster {}: {}'.format(c, np.sum(dbscan_cust.cluster==c)))
# Out:
# cluster -1: 15
# cluster 0: 14983
# cluster 1: 2

# %% [markdown]
# This is likely not going to be a successful clustering algorithm with our dataset.  Nonetheless, we can take a look at how DBSCAN creates 3 clusters within our data.

# %% [markdown]
# ### DBSCAN Clustering Results
# We create a DBSCAN model where eps=126 & min_samples=2.

# %%
db_model = DBSCAN(eps=126, min_samples=2).fit(ph_crosstab_t)

# %%
dbscan_cust = ph_crosstab.copy()
dbscan_cust['cluster'] = db_model.labels_

# print our the number of observations per cluster
for c in np.unique(dbscan_cust.cluster):
        print('cluster {}: {}'.format(c, np.sum(dbscan_cust.cluster==c)))
# Out:
# cluster -1: 18
# cluster 0: 14976
# cluster 1: 4
# cluster 2: 2

# %% [markdown]
# With the clusters predicted, let's examine the purchasing habits of our 3 clusters.

# %%
dbscan_cust[dbscan_cust.cluster>=0].groupby('cluster').mean()
# Out:
# aisle    air fresheners candles  asian foods  baby accessories  \
# cluster
# 0                      0.105168     0.780649          0.044605
# 1                      0.000000     0.500000          0.000000
# 2                      0.000000     4.500000         12.500000
#
# aisle    baby bath body care  baby food formula  bakery desserts  \
# cluster
# 0                   0.040465            1.84602         0.173144
# 1                   0.000000            0.00000         0.000000
# 2                   0.000000          347.50000         0.000000
#
# aisle    baking ingredients  baking supplies decor    beauty  beers coolers  \
# cluster
# 0                  1.596554               0.113715  0.027911       0.203325
# 1                  1.000000               0.000000  0.000000       0.000000
# 2                  7.500000               0.000000  0.500000       0.000000
#
# aisle       ...        spreads        tea  tofu meat alternatives  \
# cluster     ...
# 0           ...       1.406717   1.154247                0.595353
# 1           ...      15.250000  27.500000                0.000000
# 2           ...       3.500000   5.000000                6.500000
#
# aisle    tortillas flat bread  trail mix snack mix  trash bags liners  \
# cluster
# 0                    0.916667              0.17114           0.148237
# 1                    0.000000              0.50000           0.000000
# 2                    2.000000              0.00000           0.000000
#
# aisle    vitamins supplements  water seltzer sparkling water  white wines  \
# cluster
# 0                    0.235043                       4.022503     0.131544
# 1                    1.750000                      35.000000     0.000000
# 2                    0.000000                      17.000000     0.000000
#
# aisle        yogurt
# cluster
# 0          6.847823
# 1        283.250000
# 2         35.500000
#
# [3 rows x 134 columns]

# %% [markdown]
# #### Cluster 0

# %%
# find the top 12 aisles per cluster by percentage of total purchase
top_aisle_per = dbscan_cust[dbscan_cust.cluster==0].mean() / dbscan_cust[dbscan_cust.cluster==0].mean().sum()
top_aisle_per.sort_values(ascending=False)[:12]
# Out:
# aisle
# fresh fruits                     0.113030
# fresh vegetables                 0.107129
# packaged vegetables fruits       0.054586
# yogurt                           0.043841
# packaged cheese                  0.030427
# milk                             0.027252
# water seltzer sparkling water    0.025753
# chips pretzels                   0.022457
# soy lactosefree                  0.019840
# bread                            0.017988
# refrigerated                     0.017447
# frozen produce                   0.015964
# dtype: float64

# %% [markdown]
# Cluster 0 is characterized by customers who primarily purchase fresh fruits & fresh vegetables.
#
# They are also likely to buy pacakged vegetables/fruits, yogurt, and pacakged cheese.

# %% [markdown]
# #### Cluster 1

# %%
# find the top 12 aisles per cluster by percentage of total purchase
top_aisle_per = dbscan_cust[dbscan_cust.cluster==1].mean() / dbscan_cust[dbscan_cust.cluster==1].mean().sum()
top_aisle_per.sort_values(ascending=False)[:12]
# Out:
# aisle
# yogurt                           0.251331
# energy granola bars              0.192547
# fresh fruits                     0.115572
# packaged vegetables fruits       0.042147
# frozen produce                   0.035049
# soy lactosefree                  0.031056
# water seltzer sparkling water    0.031056
# tea                              0.024401
# packaged cheese                  0.024401
# refrigerated                     0.022848
# milk                             0.019299
# nuts seeds dried fruit           0.017746
# dtype: float64

# %% [markdown]
# Cluster 1 is characterized by customers who primarily purchase yogurt, energy granola bars and fresh fruits.
#
# This appears to be a very odd cluster when compared to clusters created by Kmeans - it appears to be a very small group who may buy products for 'snacking' purposes

# %% [markdown]
# #### Cluster 2

# %%
# find the top 12 aisles per cluster by percentage of total purchase
top_aisle_per = dbscan_cust[dbscan_cust.cluster==2].mean() / dbscan_cust[dbscan_cust.cluster==2].mean().sum()
top_aisle_per.sort_values(ascending=False)[:12]
# Out:
# aisle
# baby food formula                0.319100
# fresh fruits                     0.094582
# fresh vegetables                 0.077594
# packaged vegetables fruits       0.048669
# milk                             0.036272
# packaged cheese                  0.035354
# yogurt                           0.032599
# cereal                           0.022957
# frozen produce                   0.016529
# canned jarred vegetables         0.015611
# water seltzer sparkling water    0.015611
# juice nectars                    0.014692
# dtype: float64

# %% [markdown]
# Finally, we see a cluster that is characterized by customers who primarily buy baby food formula - representing 32% of their grocery purchases.  This is again a very small cluster and a much different representation of the baby food formula cluster created by Kmeans.

# %%
#find overall top aisles for kmeans clusters
dbscan_top_aisles = set()

# get top 12 aisles for each cluster & add aisle name to top_aisles
for c in np.unique(dbscan_cust.cluster):
    for a in dbscan_cust[dbscan_cust.cluster==c].mean().sort_values(ascending=False)[:12].index.values:
        dbscan_top_aisles.add(a)
        
dbscan_top_aisles = list(dbscan_top_aisles)
dbscan_top_aisles.sort()

# %% [markdown]
# ### DBSCAN Clustering Predictions
# DBSCAN does not offer a predict method - rather, we will need to build a classifier based on our known values and predict the labels for the test dataset.

# %%
from sklearn.linear_model import LogisticRegression

# %%
# create the classifier
clf = LogisticRegression()

# The x values will simply be the scaled & PCA transformed dataset.
X = ph_crosstab_t

# The y values will by the predicted labels
y = db_model.labels_

# We can scale & transform our test dataset using the previously declared scaler & pca
X_test = dim_pipe.transform(ph_crosstab_test)

# predict
clf.fit(X, y)
c_pred = clf.predict(X_test_t)

# %%
# Predict the clusters
dbscan_cust_test = ph_crosstab_test.copy()
dbscan_cust_test['cluster'] = c_pred

# %%
# lets see the top aisles for our test dataset
dbscan_top_aisles.append('cluster')

dbscan_cust_test[dbscan_top_aisles]
# Out:
# aisle    baby food formula  bread  canned jarred vegetables  cereal  \
# user_id
# 206138                   0      1                         0       2
# 206171                   0      0                         0       0
# 206195                   0      0                         7       0
# 206199                   3      6                         0      12
# 206204                   0      0                         0       0
#
# aisle    chips pretzels  energy granola bars  fresh fruits  fresh vegetables  \
# user_id
# 206138                1                    0            33                 2
# 206171                0                    0             0                 0
# 206195                0                    0             6                 3
# 206199               18                    4            10                14
# 206204                0                    0             3                 6
#
# aisle    frozen produce  juice nectars  milk  nuts seeds dried fruit  \
# user_id
# 206138               11              2    12                       0
# 206171                0              0     0                       0
# 206195                1              1     3                       0
# 206199                0              3     5                       0
# 206204                1              0     1                       2
#
# aisle    packaged cheese  packaged vegetables fruits  refrigerated  \
# user_id
# 206138                 2                           2             0
# 206171                 4                           0             0
# 206195                 3                           4             0
# 206199                13                           3             6
# 206204                 1                           4             0
#
# aisle    soy lactosefree  tea  water seltzer sparkling water  yogurt  cluster
# user_id
# 206138                 0    0                              0       0        0
# 206171                 1    0                              6       0        0
# 206195                 0    0                              0       1        0
# 206199                 0    0                              5      48        0
# 206204                 2    0                              0       2        0

# %% [markdown]
# Based on the distribution of customers amongst our defined clusters, it is not suprising that all 5 customers are assigned to cluster 0.
#
# User 4 had a high number of yogurt purchaes, but these purchases did not represent 25% of the users order which characterizes customer that fall within cluster 1.
#
# None of our customers had high baby food formula purchases, which is why none were placed into cluster 2.

# %% [markdown]
# ## Hierarchical Clustering
# We will look at utilizing Agglomerative Clustering for our final algorithm.  Similarily to Kmeans, we will be selecting a cluster size based on silhouette and calinski-harabaz scores. I've created a function hierarchical_performance_metrics below that calculates these scores for a given dataset and cluster size.
#
# With Agglomerative Clustering, we also have the ability to look at different linkage & affinity variables.  Both are setup to be tested in the performance metric function.

# %%
def hierarchical_performance_metrics(data, clusters):
    '''
        Compute Agglomerative Clustering for various cluster values, ranging from 
        2 to k+1.  Caclucate the silhouette score and calinkski-harabaz
        score for each value, returning the results.
        
        Params
        ------
        data: The dataset to perform clustering upon
        
        clusters: The number of cluster to create
    '''
    
    # create a dataframe to hold our results
    df_results = pd.DataFrame(columns=['n_clusters', 'linkage', 'affinity', 'score_type', 'score'])

    # define parameters
    linkage = ['complete', 'average']
    affinity = ['euclidean', 'cosine']

    # Process each range
    for c in range(2, clusters+1):
        print('processing n_clusters={}, linkage=ward, affinity=euclidean'.format(c))
        
        # build model using ward linkage
        model = AgglomerativeClustering(n_clusters=c, linkage='ward').fit(data)

        # add score
        result = pd.DataFrame({'n_clusters':[c], 'linkage': ['ward'], 'affinity': ['euclidean'],'score_type': ['silhouette'], 'score': [silhouette_score(data, model.labels_)]})

        df_results = pd.concat([df_results, result], axis=0)

        # add score
        result = pd.DataFrame({'n_clusters':[c],'linkage': ['ward'],'affinity': ['euclidean'],'score_type': ['calinski harabaz'],'score': [calinski_harabaz_score(data, model.labels_)]})

        df_results = pd.concat([df_results, result], axis=0)

        # process other linkages
        for l in linkage:
            for a in affinity:
                print('processing n_clusters={}, linkage={}, affinity={}'.format(c, l, a))

                # build model
                model = AgglomerativeClustering(n_clusters=c, linkage=l, affinity=a).fit(data)

                # add score
                result = pd.DataFrame({'n_clusters':[c], 'linkage': [l], 'affinity': [a],'score_type': ['silhouette'], 'score': [silhouette_score(data, model.labels_)]})

                df_results = pd.concat([df_results, result], axis=0)

                # add score
                result = pd.DataFrame({'n_clusters':[c],'linkage': [l],'affinity': [a],'score_type': ['calinski harabaz'],'score': [calinski_harabaz_score(data, model.labels_)]})

                df_results = pd.concat([df_results, result], axis=0)

    
    return df_results

# %% [markdown]
# Calculate metrics for our dataset using cluster size up to 15.

# %%
hpm = hierarchical_performance_metrics(ph_crosstab_t, 15)
# Out:
# processing n_clusters=2, linkage=ward, affinity=euclidean
# processing n_clusters=2, linkage=complete, affinity=euclidean
# processing n_clusters=2, linkage=complete, affinity=cosine
# processing n_clusters=2, linkage=average, affinity=euclidean
# processing n_clusters=2, linkage=average, affinity=cosine
# processing n_clusters=3, linkage=ward, affinity=euclidean
# processing n_clusters=3, linkage=complete, affinity=euclidean
# processing n_clusters=3, linkage=complete, affinity=cosine
# processing n_clusters=3, linkage=average, affinity=euclidean
# processing n_clusters=3, linkage=average, affinity=cosine
# processing n_clusters=4, linkage=ward, affinity=euclidean
# processing n_clusters=4, linkage=complete, affinity=euclidean
# processing n_clusters=4, linkage=complete, affinity=cosine
# processing n_clusters=4, linkage=average, affinity=euclidean
# processing n_clusters=4, linkage=average, affinity=cosine
# processing n_clusters=5, linkage=ward, affinity=euclidean
# processing n_clusters=5, linkage=complete, affinity=euclidean
# processing n_clusters=5, linkage=complete, affinity=cosine
# processing n_clusters=5, linkage=average, affinity=euclidean
# processing n_clusters=5, linkage=average, affinity=cosine
# processing n_clusters=6, linkage=ward, affinity=euclidean
# processing n_clusters=6, linkage=complete, affinity=euclidean
# processing n_clusters=6, linkage=complete, affinity=cosine
# processing n_clusters=6, linkage=average, affinity=euclidean
# processing n_clusters=6, linkage=average, affinity=cosine
# processing n_clusters=7, linkage=ward, affinity=euclidean
# processing n_clusters=7, linkage=complete, affinity=euclidean
# processing n_clusters=7, linkage=complete, affinity=cosine
# processing n_clusters=7, linkage=average, affinity=euclidean
# processing n_clusters=7, linkage=average, affinity=cosine
# processing n_clusters=8, linkage=ward, affinity=euclidean
# processing n_clusters=8, linkage=complete, affinity=euclidean
# processing n_clusters=8, linkage=complete, affinity=cosine
# processing n_clusters=8, linkage=average, affinity=euclidean
# processing n_clusters=8, linkage=average, affinity=cosine
# processing n_clusters=9, linkage=ward, affinity=euclidean
# processing n_clusters=9, linkage=complete, affinity=euclidean
# processing n_clusters=9, linkage=complete, affinity=cosine
# processing n_clusters=9, linkage=average, affinity=euclidean
# processing n_clusters=9, linkage=average, affinity=cosine
# processing n_clusters=10, linkage=ward, affinity=euclidean
# processing n_clusters=10, linkage=complete, affinity=euclidean
# processing n_clusters=10, linkage=complete, affinity=cosine
# processing n_clusters=10, linkage=average, affinity=euclidean
# processing n_clusters=10, linkage=average, affinity=cosine
# processing n_clusters=11, linkage=ward, affinity=euclidean
# processing n_clusters=11, linkage=complete, affinity=euclidean
# processing n_clusters=11, linkage=complete, affinity=cosine
# processing n_clusters=11, linkage=average, affinity=euclidean
# processing n_clusters=11, linkage=average, affinity=cosine
# processing n_clusters=12, linkage=ward, affinity=euclidean
# processing n_clusters=12, linkage=complete, affinity=euclidean
# processing n_clusters=12, linkage=complete, affinity=cosine
# processing n_clusters=12, linkage=average, affinity=euclidean
# processing n_clusters=12, linkage=average, affinity=cosine
# processing n_clusters=13, linkage=ward, affinity=euclidean
# processing n_clusters=13, linkage=complete, affinity=euclidean
# processing n_clusters=13, linkage=complete, affinity=cosine
# processing n_clusters=13, linkage=average, affinity=euclidean
# processing n_clusters=13, linkage=average, affinity=cosine
# processing n_clusters=14, linkage=ward, affinity=euclidean
# processing n_clusters=14, linkage=complete, affinity=euclidean
# processing n_clusters=14, linkage=complete, affinity=cosine
# processing n_clusters=14, linkage=average, affinity=euclidean
# processing n_clusters=14, linkage=average, affinity=cosine
# processing n_clusters=15, linkage=ward, affinity=euclidean
# processing n_clusters=15, linkage=complete, affinity=euclidean
# processing n_clusters=15, linkage=complete, affinity=cosine
# processing n_clusters=15, linkage=average, affinity=euclidean
# processing n_clusters=15, linkage=average, affinity=cosine

# %% [markdown]
# With the metrics calculated, let's graph them to visually inspect our results

# %%
# define number of subplots & columns
total_subplots = 6
total_cols = 2

# determine the number of rows required
total_rows = total_subplots // total_cols
total_rows += total_subplots % total_cols

# setup subplot position
pos = range(1, total_subplots+1)

# create plot
fig = plt.figure(figsize=(16,18))
i=0

# define linkage and affinity options
linkage = ['ward', 'complete', 'average']
affinity = ['euclidean', 'cosine']

# loop through each linkage type
for l in linkage:
    
    # loop through each score type
    for s in np.unique(hpm[(hpm.linkage==l)].score_type):

        ax = fig.add_subplot(total_rows, total_cols, pos[i])
        ax.set_title('linkage: {}, score: {}'.format(l, s))
        ax.set_xlabel('n_clusters')
        ax.set_ylabel('{} score'.format(s))

        # loop through each affinity type
        for a in np.sort(np.unique(hpm[(hpm.linkage==l) & (hpm.score_type==s)].affinity))[::-1]:

            # create plot
            x = hpm[(hpm.linkage==l) & (hpm.score_type==s) & (hpm.affinity==a)].n_clusters
            y = hpm[(hpm.linkage==l) & (hpm.score_type==s) & (hpm.affinity==a)].score
            ax.plot(x, y, label=a)
            
        ax.legend(title='affinity type')
        i+=1

fig.savefig('../reports/figures/ac_tuning.png')
    
plt.show()

# %% [markdown]
# We will look for a value that optimizes where k=4, so that we can be consistent with our KMeans algorithms.  Using a complete or average linkaged appears to maximize our silhouette scores, where as a linkage of ward maximizes the calinski harabaz score.
#
# It appears that the optimal parameters are:
# * linkage = complete
# * n_clusters = 4
# * affinity = euclidean
#
# The parameters create the best overall calinski harabaz & silhouette scores.
#
# As we did with DBSCAN, let's take a quick look at the cluster sizes that for parameters before making a final decision.

# %%
# build the model
ac_model = AgglomerativeClustering(n_clusters=4, linkage='complete').fit(ph_crosstab_t)

# print our the number of observations per cluster
for c in np.unique(ac_model.labels_):
        print('cluster {}: {}'.format(c, np.sum(ac_model.labels_==c)))
# Out:
# cluster 0: 14994
# cluster 1: 3
# cluster 2: 2
# cluster 3: 1

# %%
# build the model
ac_model = AgglomerativeClustering(n_clusters=4, linkage='average').fit(ph_crosstab_t)

# print our the number of observations per cluster
for c in np.unique(ac_model.labels_):
        print('cluster {}: {}'.format(c, np.sum(ac_model.labels_==c)))
# Out:
# cluster 0: 14990
# cluster 1: 6
# cluster 2: 1
# cluster 3: 3

# %% [markdown]
# Based on the sneak peek, it appears that we are experiencing the same issue we had with DBSCAN, where our clusters are unbalanced.
#
# This actually aligns with the scores we see above - as our small cluster sizes translate into high silhouette scores.
#
# The scores achieved using the 'ward' linkage appear to be more realistic.  Lets select our parameters using ward and begin building our final model.

# %% [markdown]
# ### Hierarchical Clustering Results
# We create a Agglomerative Clustering model where n_clusters=4, linkage=ward

# %%
# build the model
ac_model = AgglomerativeClustering(n_clusters=4, linkage='ward').fit(ph_crosstab_t)

# %%
ac_cust = ph_crosstab.copy()
ac_cust['cluster'] = ac_model.labels_

# print our the number of observations per cluster
for c in np.unique(ac_cust.cluster):
        print('cluster {}: {}'.format(c, np.sum(ac_cust.cluster==c)))
# Out:
# cluster 0: 320
# cluster 1: 13220
# cluster 2: 91
# cluster 3: 1369

# %% [markdown]
# These results are much more balanced and appear to be more realistic.  Lets see what aisles are most popular per cluster.

# %%
ac_cust.groupby('cluster').mean()
# Out:
# aisle    air fresheners candles  asian foods  baby accessories  \
# cluster
# 0                       0.12500     1.878125          0.531250
# 1                       0.07118     0.561952          0.021256
# 2                       0.10989     3.208791          0.219780
# 3                       0.42878     2.583638          0.162162
#
# aisle    baby bath body care  baby food formula  bakery desserts  \
# cluster
# 0                   0.375000          60.150000         0.512500
# 1                   0.022617           0.516490         0.117549
# 2                   0.109890           1.285714         0.362637
# 3                   0.129291           1.867787         0.624543
#
# aisle    baking ingredients  baking supplies decor    beauty  beers coolers  \
# cluster
# 0                  4.590625               0.309375  0.050000       0.168750
# 1                  1.125946               0.082753  0.019516       0.193116
# 2                  3.747253               0.109890  0.109890       0.857143
# 3                  5.350621               0.368882  0.098612       0.318481
#
# aisle      ...       spreads        tea  tofu meat alternatives  \
# cluster    ...
# 0          ...      4.796875   2.171875                1.196875
# 1          ...      0.939713   0.768684                0.399849
# 2          ...      8.153846  12.021978                1.351648
# 3          ...      4.791088   4.472608                2.294375
#
# aisle    tortillas flat bread  trail mix snack mix  trash bags liners  \
# cluster
# 0                    3.240625             0.203125           0.406250
# 1                    0.616944             0.125719           0.092511
# 2                    1.879121             0.780220           0.483516
# 3                    3.271001             0.596786           0.607743
#
# aisle    vitamins supplements  water seltzer sparkling water  white wines  \
# cluster
# 0                    0.846875                      10.500000     0.140625
# 1                    0.170121                       2.901286     0.125265
# 2                    1.373626                      33.670330     0.021978
# 3                    0.679328                      12.173850     0.200146
#
# aisle       yogurt
# cluster
# 0        26.925000
# 1         4.663616
# 2        44.582418
# 3        22.861943
#
# [4 rows x 134 columns]

# %% [markdown]
# #### Cluster 0

# %%
# find the top 12 aisles per cluster by percentage of total purchase
top_aisle_per = ac_cust[ac_cust.cluster==0].mean() /ac_cust[ac_cust.cluster==0].mean().sum()
top_aisle_per.sort_values(ascending=False)[:12]
# Out:
# aisle
# fresh fruits                     0.117303
# baby food formula                0.110658
# fresh vegetables                 0.096095
# packaged vegetables fruits       0.052385
# yogurt                           0.049534
# milk                             0.034569
# packaged cheese                  0.034448
# water seltzer sparkling water    0.019317
# bread                            0.018989
# soy lactosefree                  0.017362
# chips pretzels                   0.016419
# crackers                         0.014528
# dtype: float64

# %% [markdown]
# Cluster 0 characterizes customers who frequently buy fresh fruits, baby food formula and fresh vegetables.

# %% [markdown]
# #### Cluster 1

# %%
# find the top 12 aisles per cluster by percentage of total purchase
top_aisle_per = ac_cust[ac_cust.cluster==1].mean() /ac_cust[ac_cust.cluster==1].mean().sum()
top_aisle_per.sort_values(ascending=False)[:12]
# Out:
# aisle
# fresh fruits                     0.115712
# fresh vegetables                 0.113935
# packaged vegetables fruits       0.056786
# yogurt                           0.043063
# packaged cheese                  0.029437
# water seltzer sparkling water    0.026790
# milk                             0.026164
# chips pretzels                   0.021105
# soy lactosefree                  0.020062
# refrigerated                     0.017645
# bread                            0.017509
# frozen produce                   0.016911
# dtype: float64

# %% [markdown]
# Cluster 1 is characterized by customers who purchase fresh fruits and fresh vegetables.
#
# They are also likely to purchase packaged vegetables/fruits and yogurt.

# %% [markdown]
# #### Cluster 2

# %%
# find the top 12 aisles per cluster by percentage of total purchase
top_aisle_per = ac_cust[ac_cust.cluster==2].mean() /ac_cust[ac_cust.cluster==2].mean().sum()
top_aisle_per.sort_values(ascending=False)[:12]
# Out:
# aisle
# fresh fruits                     0.112482
# energy granola bars              0.109052
# yogurt                           0.063540
# fresh vegetables                 0.062381
# refrigerated                     0.048050
# water seltzer sparkling water    0.047987
# packaged vegetables fruits       0.038449
# chips pretzels                   0.031605
# soy lactosefree                  0.023790
# milk                             0.022600
# packaged cheese                  0.021253
# crackers                         0.017416
# dtype: float64

# %% [markdown]
# Cluster 2 is characterized by customers who purchase fresh fruits and energy granola bars.
#
# They are also likley to buy yogurt & fresh vegetables.

# %% [markdown]
# #### Cluster 3

# %%
# find the top 12 aisles per cluster by percentage of total purchase
top_aisle_per = ac_cust[ac_cust.cluster==3].mean() /ac_cust[ac_cust.cluster==3].mean().sum()
top_aisle_per.sort_values(ascending=False)[:12]
# Out:
# aisle
# fresh fruits                     0.103409
# fresh vegetables                 0.094402
# packaged vegetables fruits       0.050092
# yogurt                           0.043695
# packaged cheese                  0.031449
# milk                             0.027415
# chips pretzels                   0.025371
# water seltzer sparkling water    0.023267
# soy lactosefree                  0.019175
# bread                            0.018574
# frozen meals                     0.017067
# crackers                         0.016027
# dtype: float64

# %% [markdown]
# Cluster 3 is similar to cluster 1 - it is characterized by customers who primarly purchase fresh fruits & fresh vegetables.
#
# Customers in cluster 3 are:
# * More likely to purchase milk & chips/pretzels over sparking water.
# * More likley to purchase frozen meals & crackers than frozen produce

# %%
#find overall top aisles for kmeans clusters
ac_top_aisles = set()

# get top 12 aisles for each cluster & add aisle name to top_aisles
for c in np.unique(ac_cust.cluster):
    for a in ac_cust[ac_cust.cluster==c].mean().sort_values(ascending=False)[:12].index.values:
        ac_top_aisles.add(a)
        
ac_top_aisles = list(ac_top_aisles)
ac_top_aisles.sort()

# %% [markdown]
# ### Hierarchical Clustering Predictions
# Agglomerative cluster also does not offer a predict method - rather, we will need to build a classifier based on our known values and predict the labels for the test dataset.

# %%
from sklearn.linear_model import LogisticRegression

# %%
# create the classifier
clf = LogisticRegression()

# The x values will simply be the scaled & PCA transformed dataset.
X = ph_crosstab_t

# The y values will by the predicted labels
y = ac_model.labels_

# We can scale & transform our test dataset using the previously declared scaler & pca
X_test = dim_pipe.transform(ph_crosstab_test)

# predict
clf.fit(X, y)
c_pred = clf.predict(X_test_t)

# %%
# Predict the clusters
ac_cust_test = ph_crosstab_test.copy()
ac_cust_test['cluster'] = c_pred

# %%
# lets see the top aisles for our test dataset
ac_top_aisles.append('cluster')

ac_cust_test[ac_top_aisles]
# Out:
# aisle    baby food formula  bread  chips pretzels  crackers  \
# user_id
# 206138                   0      1               1         0
# 206171                   0      0               0         5
# 206195                   0      0               0         0
# 206199                   3      6              18        15
# 206204                   0      0               0         0
#
# aisle    energy granola bars  fresh fruits  fresh vegetables  frozen meals  \
# user_id
# 206138                     0            33                 2             0
# 206171                     0             0                 0             0
# 206195                     0             6                 3             0
# 206199                     4            10                14             3
# 206204                     0             3                 6             3
#
# aisle    frozen produce  milk  packaged cheese  packaged vegetables fruits  \
# user_id
# 206138               11    12                2                           2
# 206171                0     0                4                           0
# 206195                1     3                3                           4
# 206199                0     5               13                           3
# 206204                1     1                1                           4
#
# aisle    refrigerated  soy lactosefree  water seltzer sparkling water  yogurt  \
# user_id
# 206138              0                0                              0       0
# 206171              0                1                              6       0
# 206195              0                0                              0       1
# 206199              6                0                              5      48
# 206204              0                2                              0       2
#
# aisle    cluster
# user_id
# 206138         1
# 206171         1
# 206195         1
# 206199         3
# 206204         1

# %% [markdown]
# Looking at our predictions, I feel the hierarchical clustering classifier has produce excellent results.
#
# Users 1,2,3 & 5 were placed into cluster 1.  None of these customer make primary purchases of baby food formula or energy granola bars - eliminating the chances of being placed into cluster 0 or 2.
#
# Their purchases are representative of cluster 1, with focus on fresh fruits & vegetables, packaged vegetables & fruits, yogurt- this is representative of purchases
#
#
# fresh fruits                     0.115712
# fresh vegetables                 0.113935
# packaged vegetables fruits       0.056786
# yogurt                           0.043063
# packaged cheese                  0.029437
# water seltzer sparkling water    0.026790
# milk                             0.026164
# chips pretzels                   0.021105
# soy lactosefree                  0.020062
# refrigerated                     0.017645
# bread                            0.017509
# frozen produce
#
# pirmary purchases of fresh fruits & vegetables.  We also see purchases in aisles such as packaged vegetables/fruits, yogurt & packaged cheese.
#
# User 4 was placed into cluster 3 - this is representative of the users higher purchase volume in fresh fruits & vegetables, as well as a higher volume in yogurt & packaged cheese.

# %% [markdown]
# ## Conclusions
# In this notebook we looked at 3 algorithms for clustering customers based on purchase history.
#
# We found that DBSCAN performed the worst, failing to successfully create clusters that accurately described our data.
#
# KMeans and Agglomerative Clustering performed well.  Both algorithms created 4 similar clusters that described customer purchase patterns.  Agglomerative Clustering appears to have created slightly more accurate results.  An example of this can be viewed by our cluster popularized by the purchase of baby food formula -
#
# Agglomerative clustering placed the top 4 aisles as:
#
# 1. fresh fruits
# 2. baby food formula
# 3. fresh vegetables
# 4. packaged vegetables fruits
#
# KMeans placed the top 4 aisles as:
#
# 1. baby food formula
# 2. fresh fruits
# 3. fresh vegetables
# 4. packaged vegetables fruits
#
# Agglomerative clustering characterizes customers based on the primary purchase of fresh fruits, followed closley by baby food formula and fresh vegetables.
#
# Kmeans characterizes customers based on the primary purchase of baby food formula.  Fresh fruits and fresh vegetables are   depiction of the cluster makes is seem that customers primarily buy baby formula, followed by fresh fruits and fresh vegtables trailing much further behind.

# %%
aisle_summary
# Out:
#    baby food formula      bread  chips pretzels   crackers  \
# 0          60.150000  10.321875        8.925000   7.896875
# 1           0.516490   1.896142        2.285552   1.400530
# 2           1.285714   9.428571       22.175824  12.219780
# 3           1.867787   9.718042       13.274653   8.385683
#
#    energy granola bars  fresh fruits  fresh vegetables  frozen meals  \
# 0             6.731250     63.762500         52.234375      4.028125
# 1             1.320197     12.531241         12.338729      1.098638
# 2            76.516484     78.923077         43.769231      4.043956
# 3             5.634039     54.105186         49.392257      8.929876
#
#    frozen produce       milk  packaged cheese  packaged vegetables fruits  \
# 0        7.668750  18.790625        18.725000                   28.475000
# 1        1.831392   2.833434         3.187973                    6.149697
# 2        9.032967  15.857143        14.912088                   26.978022
# 3        7.466764  14.344047        16.454346                   26.208912
#
#    refrigerated  soy lactosefree  water seltzer sparkling water     yogurt
# 0      6.568750         9.437500                      10.500000  26.925000
# 1      1.910893         2.172693                       2.901286   4.663616
# 2     33.714286        16.692308                      33.670330  44.582418
# 3      8.126370        10.032871                      12.173850  22.861943

# %%
aisle_summary.iloc[0] / aisle_summary.iloc[0].sum()
# Out:
# baby food formula                0.176320
# bread                            0.030257
# chips pretzels                   0.026162
# crackers                         0.023148
# energy granola bars              0.019732
# fresh fruits                     0.186910
# fresh vegetables                 0.153117
# frozen meals                     0.011808
# frozen produce                   0.022480
# milk                             0.055082
# packaged cheese                  0.054889
# packaged vegetables fruits       0.083470
# refrigerated                     0.019255
# soy lactosefree                  0.027665
# water seltzer sparkling water    0.030779
# yogurt                           0.078926
# Name: 0, dtype: float64

# %% [markdown]
# # NYC MTA Turnstile Data Cleaning
# ___

# %% [markdown]
# ## 1. Data Description & Purpose
# ---

# %% [markdown]
# We will be analysing NYC MTA Turnstile dataset - which tracks passenger entries & exist from subway stations throughtout NYC.  The data is summarized at a 4 hour interval.
#
# [Source](http://web.mta.info/developers/turnstile.html)
#
# [Field Descriptions](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt)
#
# The purpose of this analysis is to identify the busyness of the NYC subway system during the August to October months.  We will do this by identifying total ridership per station per day over the months of August to October (2016) timeframe.
#
# It would have been ideal to summarize data over the span of 3 years, averaging daily ridership over the 3 years to eliminate any annomalies.  However, initial observations of the data did not allow this for several reasons:
# * a) Beginning mid-October 2014, the MTA changed the way they collected turnstile data.  As a result, the datasets differ before & after October 2014 - therefore 2014 was dropped.
# * b) Station names appear to different between the 2015 & 2016 datasets (it appears nomenclature was changed at some point - 'St' versus 'Street', 'Av' versus 'Ave' for example).  A mapping of station names could be created, but for the time constraints around this project, we will not undertake this task - therfore 2015 was dropped.
#
# As a result, we will only use the August to October 2016 dataset.

# %% [markdown]
# ## 2. Data Download
# ___

# %% [markdown]
# We can access the data files from the mta website (link provided above).  I've manually keyed the data files we need in the below function - running this function will auto download the files and place them in the ./data directory.

# %%
import wget

# Set the url
url_template = 'http://web.mta.info/developers/data/nyct/turnstile/turnstile_%s.txt'

# I've listed the set of files that we need to cover the span of Aug 2017 - Oct 2017
for date in ['160806','160813','160820','160827','160903','160910','160917','160924','161001','161008','161015','161022','161029']:  
    
    # build the url
    url = url_template % date
    
    # Uncomment below to begin download
    #wget.download(url, './data/')
    #print(date, 'file downloaded')

# %% [markdown]
# ## 3. Import Data
#
# With the data downloaded, we can import each data file into a python structure.  We begin organizing this turnstile data so that we can analyze the total number of passengers that pass through a turnstile each day.
#
# The dictionary data structure will be as follows:
#
# **key:** turnstile ID
#
# **value:** [[timestamp], [timestamp], [timestamp] .... ]]
#
# Let's create a function to read in a MTA data file, and return the above structure

# %%
import csv
from collections import defaultdict

def read_csv(file):
    """
        Accepts an MTA turnstile data file, parses each line, and returns an 
        organized dictionary representing a list of timestamps (value) for each
        turnstile id (key)
    """
    
    # create our empty dictionary
    # defaultdict allows us to return an empty list for indicies that do not yet exist
    data = defaultdict(list)
    
    # loop through the input file
    with open(file, 'r') as csv_file:

        reader = csv.reader(csv_file)

        # update user what we are doing
        print('Reading {} ...'.format(file))

        # for each row in the file
        for i, row in enumerate(reader):

            # we know that the first row is headers, so we skip it
            if i != 0: 
                
                # create turnstile id
                ts_id = tuple(row[:6])
                
                # create timestamp data
                ts_timestamp = row[6:]
                
                # add value to dictionary
                data[ts_id].append(ts_timestamp)
    
    return data

# %%
# create the list of the files we are going to use
filenames = [
    './data/turnstile_160806.txt',
    './data/turnstile_160813.txt',
    './data/turnstile_160820.txt',
    './data/turnstile_160827.txt',
    './data/turnstile_160903.txt',
    './data/turnstile_160910.txt',
    './data/turnstile_160917.txt',
    './data/turnstile_160924.txt',
    './data/turnstile_161001.txt',
    './data/turnstile_161008.txt',
    './data/turnstile_161015.txt',
    './data/turnstile_161022.txt',    
    './data/turnstile_161029.txt']
 
    
# import the data into raw_data
raw_data = [read_csv(f) for f in filenames]
# Out:
# Reading ./data/turnstile_160806.txt ...
# Reading ./data/turnstile_160813.txt ...
# Reading ./data/turnstile_160820.txt ...
# Reading ./data/turnstile_160827.txt ...
# Reading ./data/turnstile_160903.txt ...
# Reading ./data/turnstile_160910.txt ...
# Reading ./data/turnstile_160917.txt ...
# Reading ./data/turnstile_160924.txt ...
# Reading ./data/turnstile_161001.txt ...
# Reading ./data/turnstile_161008.txt ...
# Reading ./data/turnstile_161015.txt ...
# Reading ./data/turnstile_161022.txt ...
# Reading ./data/turnstile_161029.txt ...

# %%
# Take a sneak peak at our data so far
sample_data = list(raw_data[0].items())[:1]
#print(sample_data)

# %% [markdown]
# ## 4. Remove Unneccessary Data Fields
# ___

# %% [markdown]
# At the moment, we have our MTA dataset loaded - which includes fields that we do not need for this analysis.  Let's go ahead and cut the additional fields out.
#
# We can manipulate the current data so that we only have the timestamp and cumulative passenger count.
#
# The data structure we are trying to achieve is as follows:
#
# {turnstile ID:
#
#     [
#
#         [timestamp, passenger counts],
#
#         [timestamp, passenger counts],
#
#         [timestamp, passenger counts],
#
#         ....
#
#     ]
#
# },
# {turnstile ID:
#
#     [
#
#         [timestamp, passenger counts],
#
#         [timestamp, passenger counts],
#
#         [timestamp, passenger counts],
#
#          ....
#
#     ]
#
# ),
#
# ...
#
#
# We will create a function to do this data manipulation: mta_create_timestamp

# %%
from dateutil.parser import parse
from datetime import datetime
from collections import defaultdict

def mta_create_timestamp(data):
    """
        Accepts a dictionary structure of MTA turnstile data, with the turnstile ID (key) and related 
        time stamped entrires (value).
        
        Manipulates the data to create an actual timestamp for each entry and cumulative passengers. 
    """
    
    # initialize a dictionary to store results
    ts_timestamps = defaultdict(list)
    
    # iterate over the turnstile data
    for i, (turnstile, row_data) in enumerate(data.items()):
        
        # print out our status
        if i % 100 == 0:
            print('Processing turnstile {}...'.format(turnstile))

        # for each time entry, convert to a timestamp and retain cumulative entires
        for datestr, timestr, event, cum_entries, cum_exits in row_data:
            
            # create timestamp
            timestamp = parse(datestr + ' ' + timestr)
            
            # save data back to the dictionary
            ts_timestamps[turnstile].append([timestamp, int(cum_entries)])
    
    return ts_timestamps

# %%
# create timestamped data
raw_data_timestamped = [mta_create_timestamp(raw_data[i]) for i in range(len(raw_data))]
# Out:
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT')...
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST', 'NR', 'BMT')...
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST', 'R', 'BMT')...
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST', 'JZ', 'BMT')...
# Processing turnstile ('B024', 'R211', '00-00-03', 'KINGS HWY', 'BQ', 'BMT')...
# Processing turnstile ('C012', 'R258', '01-03-01', '4AV-9 ST', 'DFGMNR', 'BMT')...
# Processing turnstile ('E001', 'R368', '00-00-00', '9 AV', 'D', 'BMT')...
# Processing turnstile ('H007', 'R248', '00-00-00', '1 AV', 'L', 'BMT')...
# Processing turnstile ('H039', 'R375', '00-00-01', 'NEW LOTS', 'L', 'BMT')...
# Processing turnstile ('J030', 'R005', '00-00-00', '85 ST-FOREST PK', 'J', 'BMT')...
# Processing turnstile ('N012', 'R035', '01-06-03', '168 ST', 'AC1', 'IND')...
# Processing turnstile ('N049', 'R084', '01-00-00', '59 ST COLUMBUS', 'ABCD1', 'IND')...
# Processing turnstile ('N067', 'R012', '00-03-02', '34 ST-PENN STA', 'ACE', 'IND')...
# Processing turnstile ('N087', 'R282', '01-06-01', 'SPRING ST', 'CE', 'IND')...
# Processing turnstile ('N102', 'R127', '01-00-02', 'JAY ST-METROTEC', 'ACF', 'IND')...
# Processing turnstile ('N124', 'R103', '00-00-03', 'BROADWAY JCT', 'ACJLZ', 'IND')...
# Processing turnstile ('N187', 'R419', '00-00-00', 'ROCKAWAY PARK B', 'AS', 'IND')...
# Processing turnstile ('N217', 'R112', '00-03-01', 'FORDHAM RD', 'BD', 'IND')...
# Processing turnstile ('N307', 'R359', '00-00-03', 'COURT SQ-23 ST', 'EMG', 'IND')...
# Processing turnstile ('N325A', 'R218', '00-05-00', 'ELMHURST AV', 'MR', 'IND')...
# Processing turnstile ('N336', 'R158', '00-03-01', 'KEW GARDENS', 'EF', 'IND')...
# Processing turnstile ('N408A', 'R256', '00-00-00', 'NASSAU ST', 'G', 'IND')...
# Processing turnstile ('N503', 'R021', '00-00-00', '42 ST-BRYANT PK', 'BDFM7', 'IND')...
# Processing turnstile ('N519A', 'R461', '01-06-00', "B'WAY-LAFAYETTE", 'BDFQ6', 'IND')...
# Processing turnstile ('N542', 'R241', '00-00-00', '15 ST-PROSPECT', 'FG', 'IND')...
# Processing turnstile ('N603', 'R303', '00-00-00', '21 ST-QNSBRIDGE', 'F', 'IND')...
# Processing turnstile ('PTH04', 'R551', '00-00-04', 'GROVE STREET', '1', 'PTH')...
# Processing turnstile ('PTH12', 'R542', '00-04-02', 'TWENTY THIRD ST', '1', 'PTH')...
# Processing turnstile ('PTH20', 'R549', '03-01-01', 'NEWARK HM HE', '1', 'PTH')...
# Processing turnstile ('R121', 'R290', '01-05-00', 'HOUSTON ST', '1', 'IRT')...
# Processing turnstile ('R142', 'R293', '01-00-02', '34 ST-PENN STA', '123ACE', 'IRT')...
# Processing turnstile ('R160A', 'R164', '00-06-01', '66 ST-LINCOLN', '1', 'IRT')...
# Processing turnstile ('R176', 'R169', '00-03-00', '137 ST CITY COL', '1', 'IRT')...
# Processing turnstile ('R203', 'R043', '00-00-01', 'WALL ST', '45', 'IRT')...
# Processing turnstile ('R221', 'R170', '01-03-00', '14 ST-UNION SQ', '456LNQR', 'IRT')...
# Processing turnstile ('R238', 'R046', '00-00-07', 'GRD CNTRL-42 ST', '4567S', 'IRT')...
# Processing turnstile ('R246', 'R177', '00-03-04', '68ST-HUNTER CO', '6', 'IRT')...
# Processing turnstile ('R262A', 'R195', '04-00-02', '161/YANKEE STAD', '4BD', 'IRT')...
# Processing turnstile ('R308', 'R344', '00-00-02', '145 ST', '3', 'IRT')...
# Processing turnstile ('R334', 'R367', '00-00-02', '233 ST', '25', 'IRT')...
# Processing turnstile ('R419', 'R326', '00-00-01', 'ZEREGA AV', '6', 'IRT')...
# Processing turnstile ('R514', 'R094', '00-05-00', 'ASTORIA BLVD', 'NQ', 'BMT')...
# Processing turnstile ('R529', 'R208', '00-00-00', '103 ST-CORONA', '7', 'IRT')...
# Processing turnstile ('R601A', 'R108', '02-00-01', 'BOROUGH HALL', '2345R', 'IRT')...
# Processing turnstile ('R622', 'R123', '00-00-01', 'FRANKLIN AV', '2345S', 'IRT')...
# Processing turnstile ('R647', 'R110', '02-05-01', 'FLATBUSH AV-B.C', '25', 'IRT')...
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT')...
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST', 'NR', 'BMT')...
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST', 'R', 'BMT')...
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST', 'JZ', 'BMT')...
# Processing turnstile ('B024', 'R211', '00-00-03', 'KINGS HWY', 'BQ', 'BMT')...
# Processing turnstile ('C012', 'R258', '01-03-01', '4AV-9 ST', 'DFGMNR', 'BMT')...
# Processing turnstile ('E001', 'R368', '00-00-00', '9 AV', 'D', 'BMT')...
# Processing turnstile ('H007', 'R248', '00-00-00', '1 AV', 'L', 'BMT')...
# Processing turnstile ('H039', 'R375', '00-00-01', 'NEW LOTS', 'L', 'BMT')...
# Processing turnstile ('J030', 'R005', '00-00-00', '85 ST-FOREST PK', 'J', 'BMT')...
# Processing turnstile ('N012', 'R035', '01-06-03', '168 ST', 'AC1', 'IND')...
# Processing turnstile ('N049', 'R084', '01-00-00', '59 ST COLUMBUS', 'ABCD1', 'IND')...
# Processing turnstile ('N067', 'R012', '00-03-02', '34 ST-PENN STA', 'ACE', 'IND')...
# Processing turnstile ('N087', 'R282', '01-06-01', 'SPRING ST', 'CE', 'IND')...
# Processing turnstile ('N102', 'R127', '01-00-02', 'JAY ST-METROTEC', 'ACF', 'IND')...
# Processing turnstile ('N124', 'R103', '00-00-03', 'BROADWAY JCT', 'ACJLZ', 'IND')...
# Processing turnstile ('N187', 'R419', '00-00-00', 'ROCKAWAY PARK B', 'AS', 'IND')...
# Processing turnstile ('N217', 'R112', '00-03-01', 'FORDHAM RD', 'BD', 'IND')...
# Processing turnstile ('N307', 'R359', '00-00-03', 'COURT SQ-23 ST', 'EMG', 'IND')...
# Processing turnstile ('N325A', 'R218', '00-05-00', 'ELMHURST AV', 'MR', 'IND')...
# Processing turnstile ('N336', 'R158', '00-03-01', 'KEW GARDENS', 'EF', 'IND')...
# Processing turnstile ('N405', 'R239', '00-06-02', 'GREENPOINT AV', 'G', 'IND')...
# Processing turnstile ('N502', 'R021', '01-00-03', '42 ST-BRYANT PK', 'BDFM7', 'IND')...
# Processing turnstile ('N519A', 'R461', '01-05-01', "B'WAY-LAFAYETTE", 'BDFQ6', 'IND')...
# Processing turnstile ('N541', 'R241', '01-06-03', '15 ST-PROSPECT', 'FG', 'IND')...
# Processing turnstile ('N602', 'R259', '00-05-01', 'ROOSEVELT ISLND', 'F', 'IND')...
# Processing turnstile ('PTH04', 'R551', '00-00-03', 'GROVE STREET', '1', 'PTH')...
# Processing turnstile ('PTH12', 'R542', '00-04-01', 'TWENTY THIRD ST', '1', 'PTH')...
# Processing turnstile ('PTH20', 'R549', '03-01-00', 'NEWARK HM HE', '1', 'PTH')...
# Processing turnstile ('R121', 'R290', '01-03-00', 'HOUSTON ST', '1', 'IRT')...
# Processing turnstile ('R142', 'R293', '01-00-01', '34 ST-PENN STA', '123ACE', 'IRT')...
# Processing turnstile ('R160A', 'R164', '00-06-00', '66 ST-LINCOLN', '1', 'IRT')...
# Processing turnstile ('R176', 'R169', '00-00-03', '137 ST CITY COL', '1', 'IRT')...
# Processing turnstile ('R203', 'R043', '00-00-00', 'WALL ST', '45', 'IRT')...
# Processing turnstile ('R221', 'R170', '01-00-02', '14 ST-UNION SQ', '456LNQR', 'IRT')...
# Processing turnstile ('R238', 'R046', '00-00-06', 'GRD CNTRL-42 ST', '4567S', 'IRT')...
# Processing turnstile ('R246', 'R177', '00-03-03', '68ST-HUNTER CO', '6', 'IRT')...
# Processing turnstile ('R262A', 'R195', '04-00-01', '161/YANKEE STAD', '4BD', 'IRT')...
# Processing turnstile ('R308', 'R344', '00-00-01', '145 ST', '3', 'IRT')...
# Processing turnstile ('R334', 'R367', '00-00-01', '233 ST', '25', 'IRT')...
# Processing turnstile ('R419', 'R326', '00-00-00', 'ZEREGA AV', '6', 'IRT')...
# Processing turnstile ('R514', 'R094', '00-03-00', 'ASTORIA BLVD', 'NQ', 'BMT')...
# Processing turnstile ('R528', 'R097', '00-06-02', 'JUNCTION BLVD', '7', 'IRT')...
# Processing turnstile ('R601A', 'R108', '02-00-00', 'BOROUGH HALL', '2345R', 'IRT')...
# Processing turnstile ('R622', 'R123', '00-00-00', 'FRANKLIN AV', '2345S', 'IRT')...
# Processing turnstile ('R647', 'R110', '02-05-00', 'FLATBUSH AV-B.C', '25', 'IRT')...
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT')...
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST', 'NR', 'BMT')...
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST', 'R', 'BMT')...
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST', 'JZ', 'BMT')...
# Processing turnstile ('B024', 'R211', '00-00-03', 'KINGS HWY', 'BQ', 'BMT')...
# Processing turnstile ('C012', 'R258', '01-03-01', '4AV-9 ST', 'DFGMNR', 'BMT')...
# Processing turnstile ('E001', 'R368', '00-00-00', '9 AV', 'D', 'BMT')...
# Processing turnstile ('H007', 'R248', '00-00-00', '1 AV', 'L', 'BMT')...
# Processing turnstile ('H039', 'R375', '00-00-01', 'NEW LOTS', 'L', 'BMT')...
# Processing turnstile ('J030', 'R005', '00-00-00', '85 ST-FOREST PK', 'J', 'BMT')...
# Processing turnstile ('N012', 'R035', '01-06-03', '168 ST', 'AC1', 'IND')...
# Processing turnstile ('N049', 'R084', '01-00-00', '59 ST COLUMBUS', 'ABCD1', 'IND')...
# Processing turnstile ('N067', 'R012', '00-03-02', '34 ST-PENN STA', 'ACE', 'IND')...
# Processing turnstile ('N087', 'R282', '01-06-01', 'SPRING ST', 'CE', 'IND')...
# Processing turnstile ('N102', 'R127', '01-00-02', 'JAY ST-METROTEC', 'ACF', 'IND')...
# Processing turnstile ('N124', 'R103', '00-00-03', 'BROADWAY JCT', 'ACJLZ', 'IND')...
# Processing turnstile ('N187', 'R419', '00-00-00', 'ROCKAWAY PARK B', 'AS', 'IND')...
# Processing turnstile ('N217', 'R112', '00-03-01', 'FORDHAM RD', 'BD', 'IND')...
# Processing turnstile ('N307', 'R359', '00-06-00', 'COURT SQ-23 ST', 'EMG', 'IND')...
# Processing turnstile ('N325A', 'R218', '00-05-01', 'ELMHURST AV', 'MR', 'IND')...
# Processing turnstile ('N336', 'R158', '00-03-02', 'KEW GARDENS', 'EF', 'IND')...
# Processing turnstile ('N408A', 'R256', '00-00-01', 'NASSAU ST', 'G', 'IND')...
# Processing turnstile ('N503', 'R021', '00-00-00', '42 ST-BRYANT PK', 'BDFM7', 'IND')...
# Processing turnstile ('N519A', 'R461', '01-06-00', "B'WAY-LAFAYETTE", 'BDFQ6', 'IND')...
# Processing turnstile ('N542', 'R241', '00-00-02', '15 ST-PROSPECT', 'FG', 'IND')...
# Processing turnstile ('N603', 'R303', '00-00-02', '21 ST-QNSBRIDGE', 'F', 'IND')...
# Processing turnstile ('PTH04', 'R551', '00-00-06', 'GROVE STREET', '1', 'PTH')...
# Processing turnstile ('PTH13', 'R541', '00-00-00', 'THIRTY ST', '1', 'PTH')...
# Processing turnstile ('PTH20', 'R549', '03-01-04', 'NEWARK HM HE', '1', 'PTH')...
# Processing turnstile ('R121', 'R290', '01-06-01', 'HOUSTON ST', '1', 'IRT')...
# Processing turnstile ('R142', 'R293', '01-06-01', '34 ST-PENN STA', '123ACE', 'IRT')...
# Processing turnstile ('R161A', 'R452', '01-00-02', '72 ST', '123', 'IRT')...
# Processing turnstile ('R177', 'R273', '01-00-02', '145 ST', '1', 'IRT')...
# Processing turnstile ('R203', 'R043', '00-03-01', 'WALL ST', '45', 'IRT')...
# Processing turnstile ('R221', 'R170', '01-05-00', '14 ST-UNION SQ', '456LNQR', 'IRT')...
# Processing turnstile ('R238', 'R046', '00-03-01', 'GRD CNTRL-42 ST', '4567S', 'IRT')...
# Processing turnstile ('R247', 'R178', '01-00-01', '77 ST', '6', 'IRT')...
# Processing turnstile ('R262B', 'R195', '05-00-00', '161/YANKEE STAD', '4BD', 'IRT')...
# Processing turnstile ('R310', 'R053', '01-00-00', '3 AV-149 ST', '25', 'IRT')...
# Processing turnstile ('R335', 'R444', '00-00-01', 'NEREID AV', '25', 'IRT')...
# Processing turnstile ('R419', 'R326', '00-05-01', 'ZEREGA AV', '6', 'IRT')...
# Processing turnstile ('R515', 'R095', '00-00-02', 'ASTORIA DITMARS', 'NQ', 'BMT')...
# Processing turnstile ('R529', 'R208', '00-00-04', '103 ST-CORONA', '7', 'IRT')...
# Processing turnstile ('R601A', 'R108', '02-00-05', 'BOROUGH HALL', '2345R', 'IRT')...
# Processing turnstile ('R622', 'R123', '00-00-05', 'FRANKLIN AV', '2345S', 'IRT')...
# Processing turnstile ('R647', 'R110', '02-05-01', 'FLATBUSH AV-B.C', '25', 'IRT')...
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT')...
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST', 'NR', 'BMT')...
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST', 'R', 'BMT')...
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST', 'JZ', 'BMT')...
# Processing turnstile ('B024', 'R211', '00-00-03', 'KINGS HWY', 'BQ', 'BMT')...
# Processing turnstile ('C012', 'R258', '01-03-01', '4AV-9 ST', 'DFGMNR', 'BMT')...
# Processing turnstile ('E001', 'R368', '00-00-00', '9 AV', 'D', 'BMT')...
# Processing turnstile ('H007', 'R248', '00-00-00', '1 AV', 'L', 'BMT')...
# Processing turnstile ('H039', 'R375', '00-00-01', 'NEW LOTS', 'L', 'BMT')...
# Processing turnstile ('J030', 'R005', '00-00-00', '85 ST-FOREST PK', 'J', 'BMT')...
# Processing turnstile ('N012', 'R035', '01-06-03', '168 ST', 'AC1', 'IND')...
# Processing turnstile ('N049', 'R084', '01-00-00', '59 ST COLUMBUS', 'ABCD1', 'IND')...
# Processing turnstile ('N067', 'R012', '00-03-02', '34 ST-PENN STA', 'ACE', 'IND')...
# Processing turnstile ('N087', 'R282', '01-06-01', 'SPRING ST', 'CE', 'IND')...
# Processing turnstile ('N102', 'R127', '01-00-02', 'JAY ST-METROTEC', 'ACF', 'IND')...
# Processing turnstile ('N124', 'R103', '00-00-03', 'BROADWAY JCT', 'ACJLZ', 'IND')...
# Processing turnstile ('N187', 'R419', '00-00-00', 'ROCKAWAY PARK B', 'AS', 'IND')...
# Processing turnstile ('N217', 'R112', '00-03-01', 'FORDHAM RD', 'BD', 'IND')...
# Processing turnstile ('N307', 'R359', '00-06-00', 'COURT SQ-23 ST', 'EMG', 'IND')...
# Processing turnstile ('N325A', 'R218', '00-05-01', 'ELMHURST AV', 'MR', 'IND')...
# Processing turnstile ('N336', 'R158', '00-03-02', 'KEW GARDENS', 'EF', 'IND')...
# Processing turnstile ('N408A', 'R256', '00-00-01', 'NASSAU ST', 'G', 'IND')...
# Processing turnstile ('N503', 'R021', '00-00-00', '42 ST-BRYANT PK', 'BDFM7', 'IND')...
# Processing turnstile ('N519A', 'R461', '01-06-00', "B'WAY-LAFAYETTE", 'BDFQ6', 'IND')...
# Processing turnstile ('N542', 'R241', '00-00-02', '15 ST-PROSPECT', 'FG', 'IND')...
# Processing turnstile ('N601', 'R319', '00-05-01', 'LEXINGTON AV/63', 'F', 'IND')...
# Processing turnstile ('PTH03', 'R552', '00-01-06', 'JOURNAL SQUARE', '1', 'PTH')...
# Processing turnstile ('PTH12', 'R542', '00-00-00', 'TWENTY THIRD ST', '1', 'PTH')...
# Processing turnstile ('PTH20', 'R549', '03-00-02', 'NEWARK HM HE', '1', 'PTH')...
# Processing turnstile ('R119', 'R320', '00-00-00', 'CANAL ST', '1', 'IRT')...
# Processing turnstile ('R141', 'R031', '00-03-01', '34 ST-PENN STA', '123', 'IRT')...
# Processing turnstile ('R160', 'R164', '02-05-01', '66 ST-LINCOLN', '1', 'IRT')...
# Processing turnstile ('R175', 'R169', '01-00-02', '137 ST CITY COL', '1', 'IRT')...
# Processing turnstile ('R202', 'R042', '00-00-00', 'BOWLING GREEN', '45', 'IRT')...
# Processing turnstile ('R220', 'R160', '01-00-02', 'ASTOR PL', '6', 'IRT')...
# Processing turnstile ('R237B', 'R047', '01-00-01', 'GRD CNTRL-42 ST', '4567S', 'IRT')...
# Processing turnstile ('R246', 'R177', '00-00-04', '68ST-HUNTER CO', '6', 'IRT')...
# Processing turnstile ('R262', 'R195', '03-03-00', '161/YANKEE STAD', '4BD', 'IRT')...
# Processing turnstile ('R307', 'R207', '01-00-00', '135 ST', '23', 'IRT')...
# Processing turnstile ('R332', 'R365', '00-00-01', '219 ST', '25', 'IRT')...
# Processing turnstile ('R418', 'R106', '00-00-01', 'CASTLE HILL AV', '6', 'IRT')...
# Processing turnstile ('R513', 'R093', '00-03-01', '30 AV', 'NQ', 'BMT')...
# Processing turnstile ('R528', 'R097', '00-03-00', 'JUNCTION BLVD', '7', 'IRT')...
# Processing turnstile ('R550', 'R072', '00-05-00', '34 ST-HUDSON YD', '7', 'IRT')...
# Processing turnstile ('R621', 'R060', '00-00-00', 'EASTN PKWY-MUSM', '23', 'IRT')...
# Processing turnstile ('R644', 'R135', '01-06-01', 'NEWKIRK AV', '25', 'IRT')...
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT')...
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST', 'NR', 'BMT')...
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST', 'R', 'BMT')...
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST', 'JZ', 'BMT')...
# Processing turnstile ('B024', 'R211', '00-00-03', 'KINGS HWY', 'BQ', 'BMT')...
# Processing turnstile ('C012', 'R258', '01-03-01', '4AV-9 ST', 'DFGMNR', 'BMT')...
# Processing turnstile ('E001', 'R368', '00-00-00', '9 AV', 'D', 'BMT')...
# Processing turnstile ('H007', 'R248', '00-00-00', '1 AV', 'L', 'BMT')...
# Processing turnstile ('H039', 'R375', '00-00-01', 'NEW LOTS', 'L', 'BMT')...
# Processing turnstile ('J030', 'R005', '00-00-00', '85 ST-FOREST PK', 'J', 'BMT')...
# Processing turnstile ('N012', 'R035', '01-06-03', '168 ST', 'AC1', 'IND')...
# Processing turnstile ('N049', 'R084', '01-00-00', '59 ST COLUMBUS', 'ABCD1', 'IND')...
# Processing turnstile ('N067', 'R012', '00-03-02', '34 ST-PENN STA', 'ACE', 'IND')...
# Processing turnstile ('N087', 'R282', '01-06-01', 'SPRING ST', 'CE', 'IND')...
# Processing turnstile ('N102', 'R127', '01-00-02', 'JAY ST-METROTEC', 'ACF', 'IND')...
# Processing turnstile ('N124', 'R103', '00-00-03', 'BROADWAY JCT', 'ACJLZ', 'IND')...
# Processing turnstile ('N187', 'R419', '00-00-00', 'ROCKAWAY PARK B', 'AS', 'IND')...
# Processing turnstile ('N217', 'R112', '00-03-01', 'FORDHAM RD', 'BD', 'IND')...
# Processing turnstile ('N307', 'R359', '00-06-00', 'COURT SQ-23 ST', 'EMG', 'IND')...
# Processing turnstile ('N325A', 'R218', '00-05-01', 'ELMHURST AV', 'MR', 'IND')...
# Processing turnstile ('N336', 'R158', '00-03-02', 'KEW GARDENS', 'EF', 'IND')...
# Processing turnstile ('N408A', 'R256', '00-00-01', 'NASSAU ST', 'G', 'IND')...
# Processing turnstile ('N503', 'R021', '00-00-00', '42 ST-BRYANT PK', 'BDFM7', 'IND')...
# Processing turnstile ('N519A', 'R461', '01-06-00', "B'WAY-LAFAYETTE", 'BDFQ6', 'IND')...
# Processing turnstile ('N542', 'R241', '00-00-02', '15 ST-PROSPECT', 'FG', 'IND')...
# Processing turnstile ('N603', 'R303', '00-00-02', '21 ST-QNSBRIDGE', 'F', 'IND')...
# Processing turnstile ('PTH04', 'R551', '00-00-06', 'GROVE STREET', '1', 'PTH')...
# Processing turnstile ('PTH13', 'R541', '00-00-00', 'THIRTY ST', '1', 'PTH')...
# Processing turnstile ('PTH20', 'R549', '03-01-03', 'NEWARK HM HE', '1', 'PTH')...
# Processing turnstile ('R121', 'R290', '01-06-00', 'HOUSTON ST', '1', 'IRT')...
# Processing turnstile ('R142', 'R293', '01-06-00', '34 ST-PENN STA', '123ACE', 'IRT')...
# Processing turnstile ('R161A', 'R452', '01-00-01', '72 ST', '123', 'IRT')...
# Processing turnstile ('R177', 'R273', '01-00-01', '145 ST', '1', 'IRT')...
# Processing turnstile ('R203', 'R043', '00-03-00', 'WALL ST', '45', 'IRT')...
# Processing turnstile ('R221', 'R170', '01-03-02', '14 ST-UNION SQ', '456LNQR', 'IRT')...
# Processing turnstile ('R238', 'R046', '00-00-09', 'GRD CNTRL-42 ST', '4567S', 'IRT')...
# Processing turnstile ('R247', 'R178', '01-00-00', '77 ST', '6', 'IRT')...
# Processing turnstile ('R262A', 'R195', '04-00-05', '161/YANKEE STAD', '4BD', 'IRT')...
# Processing turnstile ('R309', 'R345', '00-00-02', 'HARLEM 148 ST', '3', 'IRT')...
# Processing turnstile ('R334', 'R367', '00-05-00', '233 ST', '25', 'IRT')...
# Processing turnstile ('R419', 'R326', '00-03-00', 'ZEREGA AV', '6', 'IRT')...
# Processing turnstile ('R514', 'R094', '00-05-01', 'ASTORIA BLVD', 'NQ', 'BMT')...
# Processing turnstile ('R529', 'R208', '00-00-01', '103 ST-CORONA', '7', 'IRT')...
# Processing turnstile ('R601A', 'R108', '02-00-02', 'BOROUGH HALL', '2345R', 'IRT')...
# Processing turnstile ('R622', 'R123', '00-00-02', 'FRANKLIN AV', '2345S', 'IRT')...
# Processing turnstile ('R645', 'R110', '00-05-01', 'FLATBUSH AV-B.C', '25', 'IRT')...
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT')...
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST', 'NR', 'BMT')...
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST', 'R', 'BMT')...
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST', 'JZ', 'BMT')...
# Processing turnstile ('B024', 'R211', '00-00-03', 'KINGS HWY', 'BQ', 'BMT')...
# Processing turnstile ('C012', 'R258', '01-03-01', '4AV-9 ST', 'DFGMNR', 'BMT')...
# Processing turnstile ('D016', 'R397', '00-00-01', '86 ST', 'N', 'BMT')...
# Processing turnstile ('H006', 'R330', '01-00-02', '3 AV', 'L', 'BMT')...
# Processing turnstile ('H039', 'R375', '00-00-00', 'NEW LOTS', 'L', 'BMT')...
# Processing turnstile ('J028', 'R004', '00-00-04', '75 ST-ELDERTS', 'JZ', 'BMT')...
# Processing turnstile ('N012', 'R035', '01-06-02', '168 ST', 'AC1', 'IND')...
# Processing turnstile ('N046', 'R281', '00-06-01', '72 ST', 'BC', 'IND')...
# Processing turnstile ('N067', 'R012', '00-03-01', '34 ST-PENN STA', 'ACE', 'IND')...
# Processing turnstile ('N087', 'R282', '01-06-00', 'SPRING ST', 'CE', 'IND')...
# Processing turnstile ('N102', 'R127', '01-00-01', 'JAY ST-METROTEC', 'ACF', 'IND')...
# Processing turnstile ('N124', 'R103', '00-00-02', 'BROADWAY JCT', 'ACJLZ', 'IND')...
# Processing turnstile ('N186', 'R418', '00-05-01', 'BEACH 105 ST', 'AS', 'IND')...
# Processing turnstile ('N217', 'R112', '00-03-00', 'FORDHAM RD', 'BD', 'IND')...
# Processing turnstile ('N307', 'R359', '00-00-03', 'COURT SQ-23 ST', 'EMG', 'IND')...
# Processing turnstile ('N325A', 'R218', '00-05-00', 'ELMHURST AV', 'MR', 'IND')...
# Processing turnstile ('N336', 'R158', '00-03-01', 'KEW GARDENS', 'EF', 'IND')...
# Processing turnstile ('N408A', 'R256', '00-00-00', 'NASSAU ST', 'G', 'IND')...
# Processing turnstile ('N502', 'R021', '01-06-00', '42 ST-BRYANT PK', 'BDFM7', 'IND')...
# Processing turnstile ('N519A', 'R461', '01-05-03', "B'WAY-LAFAYETTE", 'BDFQ6', 'IND')...
# Processing turnstile ('N542', 'R241', '00-00-01', '15 ST-PROSPECT', 'FG', 'IND')...
# Processing turnstile ('N603', 'R303', '00-00-01', '21 ST-QNSBRIDGE', 'F', 'IND')...
# Processing turnstile ('PTH04', 'R551', '00-00-05', 'GROVE STREET', '1', 'PTH')...
# Processing turnstile ('PTH12', 'R542', '00-04-03', 'TWENTY THIRD ST', '1', 'PTH')...
# Processing turnstile ('PTH20', 'R549', '03-01-02', 'NEWARK HM HE', '1', 'PTH')...
# Processing turnstile ('R121', 'R290', '01-05-01', 'HOUSTON ST', '1', 'IRT')...
# Processing turnstile ('R142', 'R293', '01-00-03', '34 ST-PENN STA', '123ACE', 'IRT')...
# Processing turnstile ('R161A', 'R452', '01-00-00', '72 ST', '123', 'IRT')...
# Processing turnstile ('R177', 'R273', '01-00-00', '145 ST', '1', 'IRT')...
# Processing turnstile ('R203', 'R043', '00-00-02', 'WALL ST', '45', 'IRT')...
# Processing turnstile ('R221', 'R170', '01-03-01', '14 ST-UNION SQ', '456LNQR', 'IRT')...
# Processing turnstile ('R238', 'R046', '00-00-08', 'GRD CNTRL-42 ST', '4567S', 'IRT')...
# Processing turnstile ('R246', 'R177', '00-03-05', '68ST-HUNTER CO', '6', 'IRT')...
# Processing turnstile ('R262A', 'R195', '04-00-03', '161/YANKEE STAD', '4BD', 'IRT')...
# Processing turnstile ('R309', 'R345', '00-00-00', 'HARLEM 148 ST', '3', 'IRT')...
# Processing turnstile ('R334', 'R367', '00-00-01', '233 ST', '25', 'IRT')...
# Processing turnstile ('R419', 'R326', '00-00-00', 'ZEREGA AV', '6', 'IRT')...
# Processing turnstile ('R514', 'R094', '00-03-00', 'ASTORIA BLVD', 'NQ', 'BMT')...
# Processing turnstile ('R528', 'R097', '00-06-02', 'JUNCTION BLVD', '7', 'IRT')...
# Processing turnstile ('R601A', 'R108', '02-00-00', 'BOROUGH HALL', '2345R', 'IRT')...
# Processing turnstile ('R622', 'R123', '00-00-00', 'FRANKLIN AV', '2345S', 'IRT')...
# Processing turnstile ('R645', 'R110', '00-03-02', 'FLATBUSH AV-B.C', '25', 'IRT')...
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT')...
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST', 'NR', 'BMT')...
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST', 'R', 'BMT')...
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST', 'JZ', 'BMT')...
# Processing turnstile ('B024', 'R211', '00-00-03', 'KINGS HWY', 'BQ', 'BMT')...
# Processing turnstile ('C012', 'R258', '01-03-01', '4AV-9 ST', 'DFGMNR', 'BMT')...
# Processing turnstile ('D016', 'R397', '00-00-01', '86 ST', 'N', 'BMT')...
# Processing turnstile ('H006', 'R330', '01-00-02', '3 AV', 'L', 'BMT')...
# Processing turnstile ('H039', 'R375', '00-00-00', 'NEW LOTS', 'L', 'BMT')...
# Processing turnstile ('J028', 'R004', '00-00-04', '75 ST-ELDERTS', 'JZ', 'BMT')...
# Processing turnstile ('N012', 'R035', '01-06-02', '168 ST', 'AC1', 'IND')...
# Processing turnstile ('N046', 'R281', '00-06-01', '72 ST', 'BC', 'IND')...
# Processing turnstile ('N067', 'R012', '00-03-01', '34 ST-PENN STA', 'ACE', 'IND')...
# Processing turnstile ('N087', 'R282', '01-06-00', 'SPRING ST', 'CE', 'IND')...
# Processing turnstile ('N102', 'R127', '01-00-01', 'JAY ST-METROTEC', 'ACF', 'IND')...
# Processing turnstile ('N124', 'R103', '00-00-02', 'BROADWAY JCT', 'ACJLZ', 'IND')...
# Processing turnstile ('N186', 'R418', '00-05-01', 'BEACH 105 ST', 'AS', 'IND')...
# Processing turnstile ('N217', 'R112', '00-03-00', 'FORDHAM RD', 'BD', 'IND')...
# Processing turnstile ('N307', 'R359', '00-00-02', 'COURT SQ-23 ST', 'EMG', 'IND')...
# Processing turnstile ('N325A', 'R218', '00-03-02', 'ELMHURST AV', 'MR', 'IND')...
# Processing turnstile ('N336', 'R158', '00-03-00', 'KEW GARDENS', 'EF', 'IND')...
# Processing turnstile ('N405', 'R239', '00-06-03', 'GREENPOINT AV', 'G', 'IND')...
# Processing turnstile ('N502', 'R021', '01-00-04', '42 ST-BRYANT PK', 'BDFM7', 'IND')...
# Processing turnstile ('N519A', 'R461', '01-05-02', "B'WAY-LAFAYETTE", 'BDFQ6', 'IND')...
# Processing turnstile ('N542', 'R241', '00-00-00', '15 ST-PROSPECT', 'FG', 'IND')...
# Processing turnstile ('N603', 'R303', '00-00-00', '21 ST-QNSBRIDGE', 'F', 'IND')...
# Processing turnstile ('PTH04', 'R551', '00-00-04', 'GROVE STREET', '1', 'PTH')...
# Processing turnstile ('PTH12', 'R542', '00-04-02', 'TWENTY THIRD ST', '1', 'PTH')...
# Processing turnstile ('PTH20', 'R549', '03-01-01', 'NEWARK HM HE', '1', 'PTH')...
# Processing turnstile ('R121', 'R290', '01-03-00', 'HOUSTON ST', '1', 'IRT')...
# Processing turnstile ('R142', 'R293', '01-00-01', '34 ST-PENN STA', '123ACE', 'IRT')...
# Processing turnstile ('R160A', 'R164', '00-06-00', '66 ST-LINCOLN', '1', 'IRT')...
# Processing turnstile ('R176', 'R169', '00-00-03', '137 ST CITY COL', '1', 'IRT')...
# Processing turnstile ('R203', 'R043', '00-00-00', 'WALL ST', '45', 'IRT')...
# Processing turnstile ('R221', 'R170', '01-00-02', '14 ST-UNION SQ', '456LNQR', 'IRT')...
# Processing turnstile ('R238', 'R046', '00-00-06', 'GRD CNTRL-42 ST', '4567S', 'IRT')...
# Processing turnstile ('R246', 'R177', '00-03-03', '68ST-HUNTER CO', '6', 'IRT')...
# Processing turnstile ('R262A', 'R195', '04-00-01', '161/YANKEE STAD', '4BD', 'IRT')...
# Processing turnstile ('R308', 'R344', '00-00-01', '145 ST', '3', 'IRT')...
# Processing turnstile ('R333', 'R366', '00-00-02', '225 ST', '25', 'IRT')...
# Processing turnstile ('R418', 'R106', '00-06-00', 'CASTLE HILL AV', '6', 'IRT')...
# Processing turnstile ('R514', 'R094', '00-00-02', 'ASTORIA BLVD', 'NQ', 'BMT')...
# Processing turnstile ('R528', 'R097', '00-06-00', 'JUNCTION BLVD', '7', 'IRT')...
# Processing turnstile ('R600', 'R224', '00-00-02', 'CLARK ST', '23', 'IRT')...
# Processing turnstile ('R621', 'R060', '00-03-02', 'EASTN PKWY-MUSM', '23', 'IRT')...
# Processing turnstile ('R645', 'R110', '00-03-00', 'FLATBUSH AV-B.C', '25', 'IRT')...
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT')...
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST', 'NR', 'BMT')...
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST', 'R', 'BMT')...
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST', 'JZ', 'BMT')...
# Processing turnstile ('B024', 'R211', '00-00-03', 'KINGS HWY', 'BQ', 'BMT')...
# Processing turnstile ('C012', 'R258', '01-03-01', '4AV-9 ST', 'DFGMNR', 'BMT')...
# Processing turnstile ('D016', 'R397', '00-00-01', '86 ST', 'N', 'BMT')...
# Processing turnstile ('H006', 'R330', '01-00-02', '3 AV', 'L', 'BMT')...
# Processing turnstile ('H039', 'R375', '00-00-00', 'NEW LOTS', 'L', 'BMT')...
# Processing turnstile ('J028', 'R004', '00-00-04', '75 ST-ELDERTS', 'JZ', 'BMT')...
# Processing turnstile ('N012', 'R035', '01-06-02', '168 ST', 'AC1', 'IND')...
# Processing turnstile ('N046', 'R281', '00-06-01', '72 ST', 'BC', 'IND')...
# Processing turnstile ('N067', 'R012', '00-03-01', '34 ST-PENN STA', 'ACE', 'IND')...
# Processing turnstile ('N087', 'R282', '01-06-00', 'SPRING ST', 'CE', 'IND')...
# Processing turnstile ('N102', 'R127', '01-00-01', 'JAY ST-METROTEC', 'ACF', 'IND')...
# Processing turnstile ('N124', 'R103', '00-00-02', 'BROADWAY JCT', 'ACJLZ', 'IND')...
# Processing turnstile ('N186', 'R418', '00-05-01', 'BEACH 105 ST', 'AS', 'IND')...
# Processing turnstile ('N217', 'R112', '00-03-01', 'FORDHAM RD', 'BD', 'IND')...
# Processing turnstile ('N307', 'R359', '00-00-03', 'COURT SQ-23 ST', 'EMG', 'IND')...
# Processing turnstile ('N325A', 'R218', '00-05-00', 'ELMHURST AV', 'MR', 'IND')...
# Processing turnstile ('N336', 'R158', '00-03-01', 'KEW GARDENS', 'EF', 'IND')...
# Processing turnstile ('N408A', 'R256', '00-00-00', 'NASSAU ST', 'G', 'IND')...
# Processing turnstile ('N502', 'R021', '01-06-00', '42 ST-BRYANT PK', 'BDFM7', 'IND')...
# Processing turnstile ('N519A', 'R461', '01-05-03', "B'WAY-LAFAYETTE", 'BDFQ6', 'IND')...
# Processing turnstile ('N542', 'R241', '00-00-01', '15 ST-PROSPECT', 'FG', 'IND')...
# Processing turnstile ('N603', 'R303', '00-00-01', '21 ST-QNSBRIDGE', 'F', 'IND')...
# Processing turnstile ('PTH04', 'R551', '00-01-03', 'GROVE STREET', '1', 'PTH')...
# Processing turnstile ('PTH13', 'R541', '00-00-04', 'THIRTY ST', '1', 'PTH')...
# Processing turnstile ('PTH20', 'R549', '03-01-07', 'NEWARK HM HE', '1', 'PTH')...
# Processing turnstile ('R122', 'R290', '02-05-01', 'HOUSTON ST', '1', 'IRT')...
# Processing turnstile ('R143', 'R032', '02-00-01', 'TIMES SQ-42 ST', '1237ACENQRS', 'IRT')...
# Processing turnstile ('R161A', 'R452', '01-00-04', '72 ST', '123', 'IRT')...
# Processing turnstile ('R178', 'R273', '00-00-01', '145 ST', '1', 'IRT')...
# Processing turnstile ('R203', 'R043', '00-05-00', 'WALL ST', '45', 'IRT')...
# Processing turnstile ('R221', 'R170', '01-06-00', '14 ST-UNION SQ', '456LNQR', 'IRT')...
# Processing turnstile ('R238', 'R046', '00-03-02', 'GRD CNTRL-42 ST', '4567S', 'IRT')...
# Processing turnstile ('R247', 'R178', '01-00-02', '77 ST', '6', 'IRT')...
# Processing turnstile ('R262B', 'R195', '05-00-01', '161/YANKEE STAD', '4BD', 'IRT')...
# Processing turnstile ('R310', 'R053', '01-00-01', '3 AV-149 ST', '25', 'IRT')...
# Processing turnstile ('R335', 'R444', '00-00-00', 'NEREID AV', '25', 'IRT')...
# Processing turnstile ('R419', 'R326', '00-05-00', 'ZEREGA AV', '6', 'IRT')...
# Processing turnstile ('R515', 'R095', '00-00-01', 'ASTORIA DITMARS', 'NQ', 'BMT')...
# Processing turnstile ('R529', 'R208', '00-00-03', '103 ST-CORONA', '7', 'IRT')...
# Processing turnstile ('R601A', 'R108', '02-00-04', 'BOROUGH HALL', '2345R', 'IRT')...
# Processing turnstile ('R622', 'R123', '00-00-04', 'FRANKLIN AV', '2345S', 'IRT')...
# Processing turnstile ('R645', 'R110', '00-06-01', 'FLATBUSH AV-B.C', '25', 'IRT')...
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT')...
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST', 'NR', 'BMT')...
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST', 'R', 'BMT')...
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST', 'JZ', 'BMT')...
# Processing turnstile ('B024', 'R211', '00-05-00', 'KINGS HWY', 'BQ', 'BMT')...
# Processing turnstile ('C012', 'R258', '01-03-02', '4AV-9 ST', 'DFGMNR', 'BMT')...
# Processing turnstile ('E001', 'R368', '00-00-00', '9 AV', 'D', 'BMT')...
# Processing turnstile ('H007', 'R248', '00-00-00', '1 AV', 'L', 'BMT')...
# Processing turnstile ('H039', 'R375', '00-00-01', 'NEW LOTS', 'L', 'BMT')...
# Processing turnstile ('J030', 'R005', '00-00-00', '85 ST-FOREST PK', 'J', 'BMT')...
# Processing turnstile ('N012', 'R035', '01-06-03', '168 ST', 'AC1', 'IND')...
# Processing turnstile ('N049', 'R084', '01-00-00', '59 ST COLUMBUS', 'ABCD1', 'IND')...
# Processing turnstile ('N067', 'R012', '00-03-02', '34 ST-PENN STA', 'ACE', 'IND')...
# Processing turnstile ('N087', 'R282', '01-06-01', 'SPRING ST', 'CE', 'IND')...
# Processing turnstile ('N102', 'R127', '01-00-02', 'JAY ST-METROTEC', 'ACF', 'IND')...
# Processing turnstile ('N124', 'R103', '00-00-03', 'BROADWAY JCT', 'ACJLZ', 'IND')...
# Processing turnstile ('N187', 'R419', '00-00-00', 'ROCKAWAY PARK B', 'AS', 'IND')...
# Processing turnstile ('N217', 'R112', '00-03-02', 'FORDHAM RD', 'BD', 'IND')...
# Processing turnstile ('N307', 'R359', '00-06-00', 'COURT SQ-23 ST', 'EMG', 'IND')...
# Processing turnstile ('N325A', 'R218', '00-05-01', 'ELMHURST AV', 'MR', 'IND')...
# Processing turnstile ('N336', 'R158', '00-03-02', 'KEW GARDENS', 'EF', 'IND')...
# Processing turnstile ('N408A', 'R256', '00-00-01', 'NASSAU ST', 'G', 'IND')...
# Processing turnstile ('N503', 'R021', '00-00-00', '42 ST-BRYANT PK', 'BDFM7', 'IND')...
# Processing turnstile ('N519A', 'R461', '01-06-00', "B'WAY-LAFAYETTE", 'BDFQ6', 'IND')...
# Processing turnstile ('N542', 'R241', '00-00-02', '15 ST-PROSPECT', 'FG', 'IND')...
# Processing turnstile ('N601A', 'R319', '01-05-00', 'LEXINGTON AV/63', 'F', 'IND')...
# Processing turnstile ('PTH04', 'R551', '00-00-01', 'GROVE STREET', '1', 'PTH')...
# Processing turnstile ('PTH12', 'R542', '00-00-04', 'TWENTY THIRD ST', '1', 'PTH')...
# Processing turnstile ('PTH20', 'R549', '03-00-06', 'NEWARK HM HE', '1', 'PTH')...
# Processing turnstile ('R120', 'R320', '01-00-00', 'CANAL ST', '1', 'IRT')...
# Processing turnstile ('R141', 'R031', '00-03-04', '34 ST-PENN STA', '123', 'IRT')...
# Processing turnstile ('R160A', 'R164', '00-00-02', '66 ST-LINCOLN', '1', 'IRT')...
# Processing turnstile ('R176', 'R169', '00-00-00', '137 ST CITY COL', '1', 'IRT')...
# Processing turnstile ('R202', 'R042', '00-00-03', 'BOWLING GREEN', '45', 'IRT')...
# Processing turnstile ('R220', 'R160', '01-03-02', 'ASTOR PL', '6', 'IRT')...
# Processing turnstile ('R238', 'R046', '00-00-00', 'GRD CNTRL-42 ST', '4567S', 'IRT')...
# Processing turnstile ('R246', 'R177', '00-03-00', '68ST-HUNTER CO', '6', 'IRT')...
# Processing turnstile ('R262', 'R195', '03-06-00', '161/YANKEE STAD', '4BD', 'IRT')...
# Processing turnstile ('R307', 'R207', '01-05-00', '135 ST', '23', 'IRT')...
# Processing turnstile ('R332', 'R365', '00-00-02', '219 ST', '25', 'IRT')...
# Processing turnstile ('R418', 'R106', '00-00-02', 'CASTLE HILL AV', '6', 'IRT')...
# Processing turnstile ('R513', 'R093', '00-03-02', '30 AV', 'NQ', 'BMT')...
# Processing turnstile ('R528', 'R097', '00-03-01', 'JUNCTION BLVD', '7', 'IRT')...
# Processing turnstile ('R550', 'R072', '00-05-01', '34 ST-HUDSON YD', '7', 'IRT')...
# Processing turnstile ('R621', 'R060', '00-00-01', 'EASTN PKWY-MUSM', '23', 'IRT')...
# Processing turnstile ('R645', 'R110', '00-03-00', 'FLATBUSH AV-B.C', '25', 'IRT')...
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT')...
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST', 'NR', 'BMT')...
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST', 'R', 'BMT')...
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST', 'JZ', 'BMT')...
# Processing turnstile ('B024', 'R211', '00-05-00', 'KINGS HWY', 'BQ', 'BMT')...
# Processing turnstile ('C012', 'R258', '01-03-02', '4AV-9 ST', 'DFGMNR', 'BMT')...
# Processing turnstile ('E001', 'R368', '00-00-00', '9 AV', 'D', 'BMT')...
# Processing turnstile ('H007', 'R248', '00-00-00', '1 AV', 'L', 'BMT')...
# Processing turnstile ('H039', 'R375', '00-00-01', 'NEW LOTS', 'L', 'BMT')...
# Processing turnstile ('J030', 'R005', '00-00-00', '85 ST-FOREST PK', 'J', 'BMT')...
# Processing turnstile ('N012', 'R035', '01-06-03', '168 ST', 'AC1', 'IND')...
# Processing turnstile ('N049', 'R084', '01-00-00', '59 ST COLUMBUS', 'ABCD1', 'IND')...
# Processing turnstile ('N067', 'R012', '00-03-02', '34 ST-PENN STA', 'ACE', 'IND')...
# Processing turnstile ('N087', 'R282', '01-06-01', 'SPRING ST', 'CE', 'IND')...
# Processing turnstile ('N102', 'R127', '01-00-02', 'JAY ST-METROTEC', 'ACF', 'IND')...
# Processing turnstile ('N124', 'R103', '00-00-03', 'BROADWAY JCT', 'ACJLZ', 'IND')...
# Processing turnstile ('N187', 'R419', '00-00-00', 'ROCKAWAY PARK B', 'AS', 'IND')...
# Processing turnstile ('N217', 'R112', '00-03-02', 'FORDHAM RD', 'BD', 'IND')...
# Processing turnstile ('N307', 'R359', '00-06-00', 'COURT SQ-23 ST', 'EMG', 'IND')...
# Processing turnstile ('N325A', 'R218', '00-05-01', 'ELMHURST AV', 'MR', 'IND')...
# Processing turnstile ('N336', 'R158', '00-03-02', 'KEW GARDENS', 'EF', 'IND')...
# Processing turnstile ('N408A', 'R256', '00-00-01', 'NASSAU ST', 'G', 'IND')...
# Processing turnstile ('N503', 'R021', '00-00-00', '42 ST-BRYANT PK', 'BDFM7', 'IND')...
# Processing turnstile ('N519A', 'R461', '01-06-00', "B'WAY-LAFAYETTE", 'BDFQ6', 'IND')...
# Processing turnstile ('N542', 'R241', '00-00-02', '15 ST-PROSPECT', 'FG', 'IND')...
# Processing turnstile ('N601A', 'R319', '01-05-00', 'LEXINGTON AV/63', 'F', 'IND')...
# Processing turnstile ('PTH04', 'R551', '00-00-01', 'GROVE STREET', '1', 'PTH')...
# Processing turnstile ('PTH12', 'R542', '00-00-04', 'TWENTY THIRD ST', '1', 'PTH')...
# Processing turnstile ('PTH20', 'R549', '03-00-06', 'NEWARK HM HE', '1', 'PTH')...
# Processing turnstile ('R120', 'R320', '01-00-00', 'CANAL ST', '1', 'IRT')...
# Processing turnstile ('R141', 'R031', '00-03-04', '34 ST-PENN STA', '123', 'IRT')...
# Processing turnstile ('R160A', 'R164', '00-00-02', '66 ST-LINCOLN', '1', 'IRT')...
# Processing turnstile ('R176', 'R169', '00-00-00', '137 ST CITY COL', '1', 'IRT')...
# Processing turnstile ('R202', 'R042', '00-00-03', 'BOWLING GREEN', '45', 'IRT')...
# Processing turnstile ('R220', 'R160', '01-03-02', 'ASTOR PL', '6', 'IRT')...
# Processing turnstile ('R238', 'R046', '00-00-00', 'GRD CNTRL-42 ST', '4567S', 'IRT')...
# Processing turnstile ('R246', 'R177', '00-03-00', '68ST-HUNTER CO', '6', 'IRT')...
# Processing turnstile ('R262', 'R195', '03-06-00', '161/YANKEE STAD', '4BD', 'IRT')...
# Processing turnstile ('R307', 'R207', '01-05-00', '135 ST', '23', 'IRT')...
# Processing turnstile ('R332', 'R365', '00-00-02', '219 ST', '25', 'IRT')...
# Processing turnstile ('R418', 'R106', '00-00-02', 'CASTLE HILL AV', '6', 'IRT')...
# Processing turnstile ('R513', 'R093', '00-03-02', '30 AV', 'NQ', 'BMT')...
# Processing turnstile ('R528', 'R097', '00-03-01', 'JUNCTION BLVD', '7', 'IRT')...
# Processing turnstile ('R550', 'R072', '00-05-01', '34 ST-HUDSON YD', '7', 'IRT')...
# Processing turnstile ('R621', 'R060', '00-00-01', 'EASTN PKWY-MUSM', '23', 'IRT')...
# Processing turnstile ('R645', 'R110', '00-03-00', 'FLATBUSH AV-B.C', '25', 'IRT')...
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT')...
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST', 'NR', 'BMT')...
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST', 'R', 'BMT')...
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST', 'JZ', 'BMT')...
# Processing turnstile ('B024', 'R211', '00-00-03', 'KINGS HWY', 'BQ', 'BMT')...
# Processing turnstile ('C012', 'R258', '01-03-01', '4AV-9 ST', 'DFGMNR', 'BMT')...
# Processing turnstile ('D016', 'R397', '00-00-01', '86 ST', 'N', 'BMT')...
# Processing turnstile ('H006', 'R330', '01-00-02', '3 AV', 'L', 'BMT')...
# Processing turnstile ('H039', 'R375', '00-00-00', 'NEW LOTS', 'L', 'BMT')...
# Processing turnstile ('J028', 'R004', '00-00-04', '75 ST-ELDERTS', 'JZ', 'BMT')...
# Processing turnstile ('N012', 'R035', '01-06-02', '168 ST', 'AC1', 'IND')...
# Processing turnstile ('N046', 'R281', '00-06-01', '72 ST', 'BC', 'IND')...
# Processing turnstile ('N067', 'R012', '00-03-01', '34 ST-PENN STA', 'ACE', 'IND')...
# Processing turnstile ('N087', 'R282', '01-06-00', 'SPRING ST', 'CE', 'IND')...
# Processing turnstile ('N102', 'R127', '01-00-01', 'JAY ST-METROTEC', 'ACF', 'IND')...
# Processing turnstile ('N124', 'R103', '00-00-02', 'BROADWAY JCT', 'ACJLZ', 'IND')...
# Processing turnstile ('N186', 'R418', '00-05-01', 'BEACH 105 ST', 'AS', 'IND')...
# Processing turnstile ('N217', 'R112', '00-03-01', 'FORDHAM RD', 'BD', 'IND')...
# Processing turnstile ('N307', 'R359', '00-00-03', 'COURT SQ-23 ST', 'EMG', 'IND')...
# Processing turnstile ('N325A', 'R218', '00-05-00', 'ELMHURST AV', 'MR', 'IND')...
# Processing turnstile ('N336', 'R158', '00-03-01', 'KEW GARDENS', 'EF', 'IND')...
# Processing turnstile ('N408A', 'R256', '00-00-00', 'NASSAU ST', 'G', 'IND')...
# Processing turnstile ('N502', 'R021', '01-06-00', '42 ST-BRYANT PK', 'BDFM7', 'IND')...
# Processing turnstile ('N519A', 'R461', '01-05-03', "B'WAY-LAFAYETTE", 'BDFQ6', 'IND')...
# Processing turnstile ('N542', 'R241', '00-00-01', '15 ST-PROSPECT', 'FG', 'IND')...
# Processing turnstile ('N601A', 'R319', '01-03-03', 'LEXINGTON AV/63', 'F', 'IND')...
# Processing turnstile ('PTH04', 'R551', '00-00-00', 'GROVE STREET', '1', 'PTH')...
# Processing turnstile ('PTH12', 'R542', '00-00-03', 'TWENTY THIRD ST', '1', 'PTH')...
# Processing turnstile ('PTH20', 'R549', '03-00-05', 'NEWARK HM HE', '1', 'PTH')...
# Processing turnstile ('R119', 'R320', '00-00-02', 'CANAL ST', '1', 'IRT')...
# Processing turnstile ('R141', 'R031', '00-03-03', '34 ST-PENN STA', '123', 'IRT')...
# Processing turnstile ('R160A', 'R164', '00-00-01', '66 ST-LINCOLN', '1', 'IRT')...
# Processing turnstile ('R175', 'R169', '01-00-04', '137 ST CITY COL', '1', 'IRT')...
# Processing turnstile ('R202', 'R042', '00-00-02', 'BOWLING GREEN', '45', 'IRT')...
# Processing turnstile ('R220', 'R160', '01-03-01', 'ASTOR PL', '6', 'IRT')...
# Processing turnstile ('R237B', 'R047', '01-00-03', 'GRD CNTRL-42 ST', '4567S', 'IRT')...
# Processing turnstile ('R246', 'R177', '00-00-06', '68ST-HUNTER CO', '6', 'IRT')...
# Processing turnstile ('R262', 'R195', '03-03-02', '161/YANKEE STAD', '4BD', 'IRT')...
# Processing turnstile ('R307', 'R207', '01-00-02', '135 ST', '23', 'IRT')...
# Processing turnstile ('R332', 'R365', '00-00-01', '219 ST', '25', 'IRT')...
# Processing turnstile ('R418', 'R106', '00-00-01', 'CASTLE HILL AV', '6', 'IRT')...
# Processing turnstile ('R513', 'R093', '00-03-01', '30 AV', 'NQ', 'BMT')...
# Processing turnstile ('R528', 'R097', '00-03-00', 'JUNCTION BLVD', '7', 'IRT')...
# Processing turnstile ('R550', 'R072', '00-05-00', '34 ST-HUDSON YD', '7', 'IRT')...
# Processing turnstile ('R621', 'R060', '00-00-00', 'EASTN PKWY-MUSM', '23', 'IRT')...
# Processing turnstile ('R645', 'R110', '00-06-00', 'FLATBUSH AV-B.C', '25', 'IRT')...
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT')...
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST', 'NR', 'BMT')...
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST', 'R', 'BMT')...
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST', 'JZ', 'BMT')...
# Processing turnstile ('B024', 'R211', '00-00-03', 'KINGS HWY', 'BQ', 'BMT')...
# Processing turnstile ('C012', 'R258', '01-03-01', '4AV-9 ST', 'DFGMNR', 'BMT')...
# Processing turnstile ('D016', 'R397', '00-00-01', '86 ST', 'N', 'BMT')...
# Processing turnstile ('H006', 'R330', '01-00-02', '3 AV', 'L', 'BMT')...
# Processing turnstile ('H039', 'R375', '00-00-00', 'NEW LOTS', 'L', 'BMT')...
# Processing turnstile ('J028', 'R004', '00-00-04', '75 ST-ELDERTS', 'JZ', 'BMT')...
# Processing turnstile ('N012', 'R035', '01-06-02', '168 ST', 'AC1', 'IND')...
# Processing turnstile ('N046', 'R281', '00-06-01', '72 ST', 'BC', 'IND')...
# Processing turnstile ('N067', 'R012', '00-03-01', '34 ST-PENN STA', 'ACE', 'IND')...
# Processing turnstile ('N087', 'R282', '01-06-00', 'SPRING ST', 'CE', 'IND')...
# Processing turnstile ('N102', 'R127', '01-00-01', 'JAY ST-METROTEC', 'ACF', 'IND')...
# Processing turnstile ('N124', 'R103', '00-00-02', 'BROADWAY JCT', 'ACJLZ', 'IND')...
# Processing turnstile ('N186', 'R418', '00-05-01', 'BEACH 105 ST', 'AS', 'IND')...
# Processing turnstile ('N217', 'R112', '00-03-01', 'FORDHAM RD', 'BD', 'IND')...
# Processing turnstile ('N307', 'R359', '00-00-03', 'COURT SQ-23 ST', 'EMG', 'IND')...
# Processing turnstile ('N325A', 'R218', '00-05-00', 'ELMHURST AV', 'MR', 'IND')...
# Processing turnstile ('N336', 'R158', '00-03-01', 'KEW GARDENS', 'EF', 'IND')...
# Processing turnstile ('N408A', 'R256', '00-00-00', 'NASSAU ST', 'G', 'IND')...
# Processing turnstile ('N502', 'R021', '01-06-00', '42 ST-BRYANT PK', 'BDFM7', 'IND')...
# Processing turnstile ('N519A', 'R461', '01-05-03', "B'WAY-LAFAYETTE", 'BDFQ6', 'IND')...
# Processing turnstile ('N542', 'R241', '00-00-01', '15 ST-PROSPECT', 'FG', 'IND')...
# Processing turnstile ('N601A', 'R319', '01-03-03', 'LEXINGTON AV/63', 'F', 'IND')...
# Processing turnstile ('PTH04', 'R551', '00-00-00', 'GROVE STREET', '1', 'PTH')...
# Processing turnstile ('PTH12', 'R542', '00-00-03', 'TWENTY THIRD ST', '1', 'PTH')...
# Processing turnstile ('PTH20', 'R549', '03-00-05', 'NEWARK HM HE', '1', 'PTH')...
# Processing turnstile ('R120', 'R320', '01-00-00', 'CANAL ST', '1', 'IRT')...
# Processing turnstile ('R141', 'R031', '00-03-04', '34 ST-PENN STA', '123', 'IRT')...
# Processing turnstile ('R160A', 'R164', '00-00-02', '66 ST-LINCOLN', '1', 'IRT')...
# Processing turnstile ('R176', 'R169', '00-00-00', '137 ST CITY COL', '1', 'IRT')...
# Processing turnstile ('R202', 'R042', '00-00-03', 'BOWLING GREEN', '45', 'IRT')...
# Processing turnstile ('R220', 'R160', '01-03-02', 'ASTOR PL', '6', 'IRT')...
# Processing turnstile ('R238', 'R046', '00-00-00', 'GRD CNTRL-42 ST', '4567S', 'IRT')...
# Processing turnstile ('R246', 'R177', '00-03-00', '68ST-HUNTER CO', '6', 'IRT')...
# Processing turnstile ('R262', 'R195', '03-06-00', '161/YANKEE STAD', '4BD', 'IRT')...
# Processing turnstile ('R307', 'R207', '01-05-00', '135 ST', '23', 'IRT')...
# Processing turnstile ('R332', 'R365', '00-00-02', '219 ST', '25', 'IRT')...
# Processing turnstile ('R418', 'R106', '00-00-02', 'CASTLE HILL AV', '6', 'IRT')...
# Processing turnstile ('R513', 'R093', '00-03-02', '30 AV', 'NQ', 'BMT')...
# Processing turnstile ('R528', 'R097', '00-03-01', 'JUNCTION BLVD', '7', 'IRT')...
# Processing turnstile ('R550', 'R072', '00-05-01', '34 ST-HUDSON YD', '7', 'IRT')...
# Processing turnstile ('R621', 'R060', '00-00-01', 'EASTN PKWY-MUSM', '23', 'IRT')...
# Processing turnstile ('R645', 'R110', '00-06-01', 'FLATBUSH AV-B.C', '25', 'IRT')...
# Processing turnstile ('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT')...
# Processing turnstile ('A030', 'R083', '01-06-00', '23 ST', 'NR', 'BMT')...
# Processing turnstile ('A049', 'R088', '02-01-01', 'CORTLANDT ST', 'R', 'BMT')...
# Processing turnstile ('A084', 'R125', '01-00-03', 'BROAD ST', 'JZ', 'BMT')...
# Processing turnstile ('B024', 'R211', '00-05-00', 'KINGS HWY', 'BQ', 'BMT')...
# Processing turnstile ('C012', 'R258', '01-03-02', '4AV-9 ST', 'DFGMNR', 'BMT')...
# Processing turnstile ('E001', 'R368', '00-00-00', '9 AV', 'D', 'BMT')...
# Processing turnstile ('H007', 'R248', '00-00-00', '1 AV', 'L', 'BMT')...
# Processing turnstile ('H039', 'R375', '00-00-01', 'NEW LOTS', 'L', 'BMT')...
# Processing turnstile ('J030', 'R005', '00-00-00', '85 ST-FOREST PK', 'J', 'BMT')...
# Processing turnstile ('N012', 'R035', '01-06-03', '168 ST', 'AC1', 'IND')...
# Processing turnstile ('N049', 'R084', '01-00-00', '59 ST COLUMBUS', 'ABCD1', 'IND')...
# Processing turnstile ('N067', 'R012', '00-03-02', '34 ST-PENN STA', 'ACE', 'IND')...
# Processing turnstile ('N087', 'R282', '01-06-01', 'SPRING ST', 'CE', 'IND')...
# Processing turnstile ('N102', 'R127', '01-00-02', 'JAY ST-METROTEC', 'ACF', 'IND')...
# Processing turnstile ('N124', 'R103', '00-00-03', 'BROADWAY JCT', 'ACJLZ', 'IND')...
# Processing turnstile ('N187', 'R419', '00-00-00', 'ROCKAWAY PARK B', 'AS', 'IND')...
# Processing turnstile ('N217', 'R112', '00-03-02', 'FORDHAM RD', 'BD', 'IND')...
# Processing turnstile ('N307', 'R359', '00-06-00', 'COURT SQ-23 ST', 'EMG', 'IND')...
# Processing turnstile ('N325A', 'R218', '00-05-01', 'ELMHURST AV', 'MR', 'IND')...
# Processing turnstile ('N336', 'R158', '00-03-02', 'KEW GARDENS', 'EF', 'IND')...
# Processing turnstile ('N408A', 'R256', '00-00-01', 'NASSAU ST', 'G', 'IND')...
# Processing turnstile ('N503', 'R021', '00-00-00', '42 ST-BRYANT PK', 'BDFM7', 'IND')...
# Processing turnstile ('N519A', 'R461', '01-06-00', "B'WAY-LAFAYETTE", 'BDFQ6', 'IND')...
# Processing turnstile ('N542', 'R241', '00-00-02', '15 ST-PROSPECT', 'FG', 'IND')...
# Processing turnstile ('N601A', 'R319', '01-05-00', 'LEXINGTON AV/63', 'F', 'IND')...
# Processing turnstile ('PTH04', 'R551', '00-00-01', 'GROVE STREET', '1', 'PTH')...
# Processing turnstile ('PTH12', 'R542', '00-00-04', 'TWENTY THIRD ST', '1', 'PTH')...
# Processing turnstile ('PTH20', 'R549', '03-00-06', 'NEWARK HM HE', '1', 'PTH')...
# Processing turnstile ('R120', 'R320', '01-00-01', 'CANAL ST', '1', 'IRT')...
# Processing turnstile ('R141', 'R031', '00-06-00', '34 ST-PENN STA', '123', 'IRT')...
# Processing turnstile ('R160A', 'R164', '00-05-00', '66 ST-LINCOLN', '1', 'IRT')...
# Processing turnstile ('R176', 'R169', '00-00-01', '137 ST CITY COL', '1', 'IRT')...
# Processing turnstile ('R202', 'R042', '00-06-00', 'BOWLING GREEN', '45', 'IRT')...
# Processing turnstile ('R221', 'R170', '01-00-00', '14 ST-UNION SQ', '456LNQR', 'IRT')...
# Processing turnstile ('R238', 'R046', '00-00-01', 'GRD CNTRL-42 ST', '4567S', 'IRT')...
# Processing turnstile ('R246', 'R177', '00-03-01', '68ST-HUNTER CO', '6', 'IRT')...
# Processing turnstile ('R262', 'R195', '03-06-01', '161/YANKEE STAD', '4BD', 'IRT')...
# Processing turnstile ('R307', 'R207', '01-05-01', '135 ST', '23', 'IRT')...
# Processing turnstile ('R333', 'R366', '00-00-00', '225 ST', '25', 'IRT')...
# Processing turnstile ('R418', 'R106', '00-03-00', 'CASTLE HILL AV', '6', 'IRT')...
# Processing turnstile ('R514', 'R094', '00-00-00', 'ASTORIA BLVD', 'NQ', 'BMT')...
# Processing turnstile ('R528', 'R097', '00-05-00', 'JUNCTION BLVD', '7', 'IRT')...
# Processing turnstile ('R600', 'R224', '00-00-00', 'CLARK ST', '23', 'IRT')...
# Processing turnstile ('R621', 'R060', '00-03-00', 'EASTN PKWY-MUSM', '23', 'IRT')...
# Processing turnstile ('R645', 'R110', '00-06-02', 'FLATBUSH AV-B.C', '25', 'IRT')...

# %%
# Take a sneak peak at our data so far
sample_data= list(raw_data_timestamped[0].items())[:1]
#print(sample_data)

# %% [markdown]
# ## 5. Summarize By Turnstile
# ___

# %% [markdown]
# We now have a list of dictionaries - each representing a one week span at MTA.  We want to combine all dictionaries so that we have a complete listing of ridership for each turnstile from August to October.
#
# We can do this using the combine_weekly_dictionaries function below.

# %%
def combine_weekly_dictionaries(data):
    """
        Accepts a list of dictionaries (each representing a two week span in MTA turnstile data), combines
        each dictionary based on turnstile id, and returns the combined dictionary for consumption.
    """

    # declare our variable to hold all data 
    combined = defaultdict(list)
    
    # loop through each dictionary 
    for d in data:
        
        # for each dictionary, loop through k, v pairs (turnstile, timestamps)
        for turnstile, time_series in d.items():
            
            # add the timeseries to the turnstile id
            combined[turnstile] += time_series
            
    return combined

# %%
# retrieves the data
timestamped_per_turnstile = combine_weekly_dictionaries(raw_data_timestamped)

# %%
# Take a sneak peak at our data so far
list(timestamped_per_turnstile.items())[:1]
# Out:
# [(('A002', 'R051', '02-00-00', '59 ST', 'NQR456', 'BMT'),
#   [[datetime.datetime(2016, 7, 30, 0, 0), 5760764],
#    [datetime.datetime(2016, 7, 30, 4, 0), 5760814],
#    [datetime.datetime(2016, 7, 30, 8, 0), 5760842],
#    [datetime.datetime(2016, 7, 30, 12, 0), 5760971],
#    [datetime.datetime(2016, 7, 30, 16, 0), 5761196],
#    [datetime.datetime(2016, 7, 30, 20, 0), 5761524],
#    [datetime.datetime(2016, 7, 31, 0, 0), 5761691],
#    [datetime.datetime(2016, 7, 31, 4, 0), 5761733],
#    [datetime.datetime(2016, 7, 31, 8, 0), 5761748],
#    [datetime.datetime(2016, 7, 31, 12, 0), 5761841],
#    [datetime.datetime(2016, 7, 31, 16, 0), 5762029],
#    [datetime.datetime(2016, 7, 31, 20, 0), 5762275],
#    [datetime.datetime(2016, 8, 1, 0, 0), 5762406],
#    [datetime.datetime(2016, 8, 1, 4, 0), 5762419],
#    [datetime.datetime(2016, 8, 1, 8, 0), 5762463],
#    [datetime.datetime(2016, 8, 1, 12, 0), 5762608],
#    [datetime.datetime(2016, 8, 1, 16, 0), 5762961],
#    [datetime.datetime(2016, 8, 1, 20, 0), 5763874],
#    [datetime.datetime(2016, 8, 2, 0, 0), 5764095],
#    [datetime.datetime(2016, 8, 2, 4, 0), 5764113],
#    [datetime.datetime(2016, 8, 2, 8, 0), 5764155],
#    [datetime.datetime(2016, 8, 2, 12, 0), 5764324],
#    [datetime.datetime(2016, 8, 2, 16, 0), 5764616],
#    [datetime.datetime(2016, 8, 2, 20, 0), 5765542],
#    [datetime.datetime(2016, 8, 3, 0, 0), 5765822],
#    [datetime.datetime(2016, 8, 3, 4, 0), 5765841],
#    [datetime.datetime(2016, 8, 3, 8, 0), 5765893],
#    [datetime.datetime(2016, 8, 3, 12, 0), 5766067],
#    [datetime.datetime(2016, 8, 3, 16, 0), 5766390],
#    [datetime.datetime(2016, 8, 3, 20, 0), 5767231],
#    [datetime.datetime(2016, 8, 4, 0, 0), 5767461],
#    [datetime.datetime(2016, 8, 4, 4, 0), 5767485],
#    [datetime.datetime(2016, 8, 4, 8, 0), 5767545],
#    [datetime.datetime(2016, 8, 4, 12, 0), 5767713],
#    [datetime.datetime(2016, 8, 4, 16, 0), 5768029],
#    [datetime.datetime(2016, 8, 4, 20, 0), 5768926],
#    [datetime.datetime(2016, 8, 5, 0, 0), 5769204],
#    [datetime.datetime(2016, 8, 5, 4, 0), 5769232],
#    [datetime.datetime(2016, 8, 5, 8, 0), 5769271],
#    [datetime.datetime(2016, 8, 5, 12, 0), 5769472],
#    [datetime.datetime(2016, 8, 5, 16, 0), 5769795],
#    [datetime.datetime(2016, 8, 5, 20, 0), 5770554],
#    [datetime.datetime(2016, 8, 6, 0, 0), 5770800],
#    [datetime.datetime(2016, 8, 6, 4, 0), 5770836],
#    [datetime.datetime(2016, 8, 6, 8, 0), 5770862],
#    [datetime.datetime(2016, 8, 6, 12, 0), 5770964],
#    [datetime.datetime(2016, 8, 6, 16, 0), 5771223],
#    [datetime.datetime(2016, 8, 6, 20, 0), 5771533],
#    [datetime.datetime(2016, 8, 7, 0, 0), 5771694],
#    [datetime.datetime(2016, 8, 7, 4, 0), 5771720],
#    [datetime.datetime(2016, 8, 7, 8, 0), 5771734],
#    [datetime.datetime(2016, 8, 7, 12, 0), 5771843],
#    [datetime.datetime(2016, 8, 7, 16, 0), 5772030],
#    [datetime.datetime(2016, 8, 7, 20, 0), 5772273],
#    [datetime.datetime(2016, 8, 8, 0, 0), 5772385],
#    [datetime.datetime(2016, 8, 8, 4, 0), 5772392],
#    [datetime.datetime(2016, 8, 8, 8, 0), 5772422],
#    [datetime.datetime(2016, 8, 8, 12, 0), 5772581],
#    [datetime.datetime(2016, 8, 8, 16, 0), 5772897],
#    [datetime.datetime(2016, 8, 8, 20, 0), 5773743],
#    [datetime.datetime(2016, 8, 9, 0, 0), 5773966],
#    [datetime.datetime(2016, 8, 9, 4, 0), 5773983],
#    [datetime.datetime(2016, 8, 9, 8, 0), 5774030],
#    [datetime.datetime(2016, 8, 9, 12, 0), 5774221],
#    [datetime.datetime(2016, 8, 9, 16, 0), 5774553],
#    [datetime.datetime(2016, 8, 9, 20, 0), 5775422],
#    [datetime.datetime(2016, 8, 10, 0, 0), 5775688],
#    [datetime.datetime(2016, 8, 10, 4, 0), 5775713],
#    [datetime.datetime(2016, 8, 10, 8, 0), 5775757],
#    [datetime.datetime(2016, 8, 10, 12, 0), 5775959],
#    [datetime.datetime(2016, 8, 10, 16, 0), 5776262],
#    [datetime.datetime(2016, 8, 10, 20, 0), 5777115],
#    [datetime.datetime(2016, 8, 11, 0, 0), 5777371],
#    [datetime.datetime(2016, 8, 11, 4, 0), 5777398],
#    [datetime.datetime(2016, 8, 11, 8, 0), 5777432],
#    [datetime.datetime(2016, 8, 11, 12, 0), 5777624],
#    [datetime.datetime(2016, 8, 11, 16, 0), 5777919],
#    [datetime.datetime(2016, 8, 11, 20, 0), 5778722],
#    [datetime.datetime(2016, 8, 12, 0, 0), 5778985],
#    [datetime.datetime(2016, 8, 12, 4, 0), 5779014],
#    [datetime.datetime(2016, 8, 12, 8, 0), 5779050],
#    [datetime.datetime(2016, 8, 12, 12, 0), 5779224],
#    [datetime.datetime(2016, 8, 12, 16, 0), 5779584],
#    [datetime.datetime(2016, 8, 12, 20, 0), 5780402],
#    [datetime.datetime(2016, 8, 13, 0, 0), 5780627],
#    [datetime.datetime(2016, 8, 13, 4, 0), 5780664],
#    [datetime.datetime(2016, 8, 13, 8, 0), 5780684],
#    [datetime.datetime(2016, 8, 13, 12, 0), 5780821],
#    [datetime.datetime(2016, 8, 13, 16, 0), 5781035],
#    [datetime.datetime(2016, 8, 13, 20, 0), 5781349],
#    [datetime.datetime(2016, 8, 14, 0, 0), 5781507],
#    [datetime.datetime(2016, 8, 14, 4, 0), 5781536],
#    [datetime.datetime(2016, 8, 14, 8, 0), 5781556],
#    [datetime.datetime(2016, 8, 14, 12, 0), 5781667],
#    [datetime.datetime(2016, 8, 14, 16, 0), 5781855],
#    [datetime.datetime(2016, 8, 14, 20, 0), 5782092],
#    [datetime.datetime(2016, 8, 15, 0, 0), 5782205],
#    [datetime.datetime(2016, 8, 15, 4, 0), 5782223],
#    [datetime.datetime(2016, 8, 15, 8, 0), 5782252],
#    [datetime.datetime(2016, 8, 15, 12, 0), 5782425],
#    [datetime.datetime(2016, 8, 15, 16, 0), 5782722],
#    [datetime.datetime(2016, 8, 15, 20, 0), 5783580],
#    [datetime.datetime(2016, 8, 16, 0, 0), 5783801],
#    [datetime.datetime(2016, 8, 16, 4, 0), 5783817],
#    [datetime.datetime(2016, 8, 16, 8, 0), 5783868],
#    [datetime.datetime(2016, 8, 16, 12, 0), 5784041],
#    [datetime.datetime(2016, 8, 16, 16, 0), 5784322],
#    [datetime.datetime(2016, 8, 16, 20, 0), 5785168],
#    [datetime.datetime(2016, 8, 17, 0, 0), 5785381],
#    [datetime.datetime(2016, 8, 17, 4, 0), 5785399],
#    [datetime.datetime(2016, 8, 17, 8, 0), 5785448],
#    [datetime.datetime(2016, 8, 17, 12, 0), 5785624],
#    [datetime.datetime(2016, 8, 17, 16, 0), 5785927],
#    [datetime.datetime(2016, 8, 17, 20, 0), 5786747],
#    [datetime.datetime(2016, 8, 18, 0, 0), 5786983],
#    [datetime.datetime(2016, 8, 18, 4, 0), 5787006],
#    [datetime.datetime(2016, 8, 18, 8, 0), 5787049],
#    [datetime.datetime(2016, 8, 18, 12, 0), 5787212],
#    [datetime.datetime(2016, 8, 18, 16, 0), 5787553],
#    [datetime.datetime(2016, 8, 18, 20, 0), 5788400],
#    [datetime.datetime(2016, 8, 19, 0, 0), 5788633],
#    [datetime.datetime(2016, 8, 19, 4, 0), 5788655],
#    [datetime.datetime(2016, 8, 19, 8, 0), 5788701],
#    [datetime.datetime(2016, 8, 19, 12, 0), 5788873],
#    [datetime.datetime(2016, 8, 19, 16, 0), 5789259],
#    [datetime.datetime(2016, 8, 19, 20, 0), 5790022],
#    [datetime.datetime(2016, 8, 20, 0, 0), 5790246],
#    [datetime.datetime(2016, 8, 20, 4, 0), 5790275],
#    [datetime.datetime(2016, 8, 20, 8, 0), 5790284],
#    [datetime.datetime(2016, 8, 20, 12, 0), 5790377],
#    [datetime.datetime(2016, 8, 20, 16, 0), 5790605],
#    [datetime.datetime(2016, 8, 20, 20, 0), 5790926],
#    [datetime.datetime(2016, 8, 21, 0, 0), 5791095],
#    [datetime.datetime(2016, 8, 21, 4, 0), 5791132],
#    [datetime.datetime(2016, 8, 21, 8, 0), 5791141],
#    [datetime.datetime(2016, 8, 21, 12, 0), 5791217],
#    [datetime.datetime(2016, 8, 21, 16, 0), 5791385],
#    [datetime.datetime(2016, 8, 21, 20, 0), 5791648],
#    [datetime.datetime(2016, 8, 22, 0, 0), 5791766],
#    [datetime.datetime(2016, 8, 22, 4, 0), 5791782],
#    [datetime.datetime(2016, 8, 22, 8, 0), 5791829],
#    [datetime.datetime(2016, 8, 22, 12, 0), 5792007],
#    [datetime.datetime(2016, 8, 22, 16, 0), 5792315],
#    [datetime.datetime(2016, 8, 22, 20, 0), 5793152],
#    [datetime.datetime(2016, 8, 23, 0, 0), 5793399],
#    [datetime.datetime(2016, 8, 23, 4, 0), 5793422],
#    [datetime.datetime(2016, 8, 23, 8, 0), 5793475],
#    [datetime.datetime(2016, 8, 23, 12, 0), 5793656],
#    [datetime.datetime(2016, 8, 23, 16, 0), 5793961],
#    [datetime.datetime(2016, 8, 23, 20, 0), 5794827],
#    [datetime.datetime(2016, 8, 24, 0, 0), 5795047],
#    [datetime.datetime(2016, 8, 24, 4, 0), 5795068],
#    [datetime.datetime(2016, 8, 24, 8, 0), 5795107],
#    [datetime.datetime(2016, 8, 24, 12, 0), 5795291],
#    [datetime.datetime(2016, 8, 24, 16, 0), 5795619],
#    [datetime.datetime(2016, 8, 24, 20, 0), 5796445],
#    [datetime.datetime(2016, 8, 25, 0, 0), 5796665],
#    [datetime.datetime(2016, 8, 25, 4, 0), 5796672],
#    [datetime.datetime(2016, 8, 25, 8, 0), 5796706],
#    [datetime.datetime(2016, 8, 25, 12, 0), 5796863],
#    [datetime.datetime(2016, 8, 25, 16, 0), 5797068],
#    [datetime.datetime(2016, 8, 25, 20, 0), 5797735],
#    [datetime.datetime(2016, 8, 26, 0, 0), 5797976],
#    [datetime.datetime(2016, 8, 26, 4, 0), 5798002],
#    [datetime.datetime(2016, 8, 26, 8, 0), 5798027],
#    [datetime.datetime(2016, 8, 26, 12, 0), 5798179],
#    [datetime.datetime(2016, 8, 26, 16, 0), 5798549],
#    [datetime.datetime(2016, 8, 26, 20, 0), 5799243],
#    [datetime.datetime(2016, 8, 27, 0, 0), 5799442],
#    [datetime.datetime(2016, 8, 27, 4, 0), 5799463],
#    [datetime.datetime(2016, 8, 27, 8, 0), 5799492],
#    [datetime.datetime(2016, 8, 27, 12, 0), 5799610],
#    [datetime.datetime(2016, 8, 27, 16, 0), 5799833],
#    [datetime.datetime(2016, 8, 27, 20, 0), 5800121],
#    [datetime.datetime(2016, 8, 28, 0, 0), 5800252],
#    [datetime.datetime(2016, 8, 28, 4, 0), 5800281],
#    [datetime.datetime(2016, 8, 28, 8, 0), 5800295],
#    [datetime.datetime(2016, 8, 28, 12, 0), 5800377],
#    [datetime.datetime(2016, 8, 28, 16, 0), 5800572],
#    [datetime.datetime(2016, 8, 28, 20, 0), 5800798],
#    [datetime.datetime(2016, 8, 29, 0, 0), 5800934],
#    [datetime.datetime(2016, 8, 29, 4, 0), 5800947],
#    [datetime.datetime(2016, 8, 29, 8, 0), 5800996],
#    [datetime.datetime(2016, 8, 29, 12, 0), 5801176],
#    [datetime.datetime(2016, 8, 29, 16, 0), 5801495],
#    [datetime.datetime(2016, 8, 29, 20, 0), 5802336],
#    [datetime.datetime(2016, 8, 30, 0, 0), 5802514],
#    [datetime.datetime(2016, 8, 30, 4, 0), 5802528],
#    [datetime.datetime(2016, 8, 30, 8, 0), 5802575],
#    [datetime.datetime(2016, 8, 30, 12, 0), 5802760],
#    [datetime.datetime(2016, 8, 30, 16, 0), 5803047],
#    [datetime.datetime(2016, 8, 30, 20, 0), 5803875],
#    [datetime.datetime(2016, 8, 31, 0, 0), 5804071],
#    [datetime.datetime(2016, 8, 31, 4, 0), 5804084],
#    [datetime.datetime(2016, 8, 31, 8, 0), 5804129],
#    [datetime.datetime(2016, 8, 31, 12, 0), 5804308],
#    [datetime.datetime(2016, 8, 31, 16, 0), 5804589],
#    [datetime.datetime(2016, 8, 31, 20, 0), 5805383],
#    [datetime.datetime(2016, 9, 1, 0, 0), 5805638],
#    [datetime.datetime(2016, 9, 1, 4, 0), 5805658],
#    [datetime.datetime(2016, 9, 1, 8, 0), 5805709],
#    [datetime.datetime(2016, 9, 1, 12, 0), 5805864],
#    [datetime.datetime(2016, 9, 1, 16, 0), 5806153],
#    [datetime.datetime(2016, 9, 1, 20, 0), 5806990],
#    [datetime.datetime(2016, 9, 2, 0, 0), 5807232],
#    [datetime.datetime(2016, 9, 2, 4, 0), 5807263],
#    [datetime.datetime(2016, 9, 2, 8, 0), 5807309],
#    [datetime.datetime(2016, 9, 2, 12, 0), 5807479],
#    [datetime.datetime(2016, 9, 2, 16, 0), 5807949],
#    [datetime.datetime(2016, 9, 2, 20, 0), 5808616],
#    [datetime.datetime(2016, 9, 3, 0, 0), 5808846],
#    [datetime.datetime(2016, 9, 3, 4, 0), 5808877],
#    [datetime.datetime(2016, 9, 3, 8, 0), 5808900],
#    [datetime.datetime(2016, 9, 3, 12, 0), 5808997],
#    [datetime.datetime(2016, 9, 3, 16, 0), 5809234],
#    [datetime.datetime(2016, 9, 3, 20, 0), 5809522],
#    [datetime.datetime(2016, 9, 4, 0, 0), 5809667],
#    [datetime.datetime(2016, 9, 4, 4, 0), 5809688],
#    [datetime.datetime(2016, 9, 4, 8, 0), 5809694],
#    [datetime.datetime(2016, 9, 4, 12, 0), 5809763],
#    [datetime.datetime(2016, 9, 4, 16, 0), 5809957],
#    [datetime.datetime(2016, 9, 4, 20, 0), 5810188],
#    [datetime.datetime(2016, 9, 5, 0, 0), 5810301],
#    [datetime.datetime(2016, 9, 5, 4, 0), 5810328],
#    [datetime.datetime(2016, 9, 5, 8, 0), 5810338],
#    [datetime.datetime(2016, 9, 5, 12, 0), 5810428],
#    [datetime.datetime(2016, 9, 5, 16, 0), 5810610],
#    [datetime.datetime(2016, 9, 5, 20, 0), 5810871],
#    [datetime.datetime(2016, 9, 6, 0, 0), 5810983],
#    [datetime.datetime(2016, 9, 6, 4, 0), 5810994],
#    [datetime.datetime(2016, 9, 6, 8, 0), 5811040],
#    [datetime.datetime(2016, 9, 6, 12, 0), 5811238],
#    [datetime.datetime(2016, 9, 6, 16, 0), 5811468],
#    [datetime.datetime(2016, 9, 6, 20, 0), 5812270],
#    [datetime.datetime(2016, 9, 7, 0, 0), 5812369],
#    [datetime.datetime(2016, 9, 7, 4, 0), 5812371],
#    [datetime.datetime(2016, 9, 7, 8, 0), 5812435],
#    [datetime.datetime(2016, 9, 7, 12, 0), 5812670],
#    [datetime.datetime(2016, 9, 7, 16, 0), 5812980],
#    [datetime.datetime(2016, 9, 7, 20, 0), 5813804],
#    [datetime.datetime(2016, 9, 8, 0, 0), 5814038],
#    [datetime.datetime(2016, 9, 8, 4, 0), 5814054],
#    [datetime.datetime(2016, 9, 8, 8, 0), 5814107],
#    [datetime.datetime(2016, 9, 8, 12, 0), 5814312],
#    [datetime.datetime(2016, 9, 8, 16, 0), 5814663],
#    [datetime.datetime(2016, 9, 8, 20, 0), 5815567],
#    [datetime.datetime(2016, 9, 9, 0, 0), 5815801],
#    [datetime.datetime(2016, 9, 9, 4, 0), 5815829],
#    [datetime.datetime(2016, 9, 9, 8, 0), 5815878],
#    [datetime.datetime(2016, 9, 9, 12, 0), 5816073],
#    [datetime.datetime(2016, 9, 9, 16, 0), 5816412],
#    [datetime.datetime(2016, 9, 9, 20, 0), 5817253],
#    [datetime.datetime(2016, 9, 10, 0, 0), 5817505],
#    [datetime.datetime(2016, 9, 10, 4, 0), 5817544],
#    [datetime.datetime(2016, 9, 10, 8, 0), 5817564],
#    [datetime.datetime(2016, 9, 10, 12, 0), 5817678],
#    [datetime.datetime(2016, 9, 10, 16, 0), 5817925],
#    [datetime.datetime(2016, 9, 10, 20, 0), 5818247],
#    [datetime.datetime(2016, 9, 11, 0, 0), 5818403],
#    [datetime.datetime(2016, 9, 11, 4, 0), 5818439],
#    [datetime.datetime(2016, 9, 11, 8, 0), 5818451],
#    [datetime.datetime(2016, 9, 11, 12, 0), 5818522],
#    [datetime.datetime(2016, 9, 11, 16, 0), 5818722],
#    [datetime.datetime(2016, 9, 11, 20, 0), 5818974],
#    [datetime.datetime(2016, 9, 12, 0, 0), 5819116],
#    [datetime.datetime(2016, 9, 12, 4, 0), 5819125],
#    [datetime.datetime(2016, 9, 12, 8, 0), 5819168],
#    [datetime.datetime(2016, 9, 12, 12, 0), 5819339],
#    [datetime.datetime(2016, 9, 12, 16, 0), 5819681],
#    [datetime.datetime(2016, 9, 12, 20, 0), 5820548],
#    [datetime.datetime(2016, 9, 13, 0, 0), 5820776],
#    [datetime.datetime(2016, 9, 13, 4, 0), 5820796],
#    [datetime.datetime(2016, 9, 13, 8, 0), 5820850],
#    [datetime.datetime(2016, 9, 13, 12, 0), 5821036],
#    [datetime.datetime(2016, 9, 13, 16, 0), 5821371],
#    [datetime.datetime(2016, 9, 13, 20, 0), 5822272],
#    [datetime.datetime(2016, 9, 14, 0, 0), 5822527],
#    [datetime.datetime(2016, 9, 14, 4, 0), 5822553],
#    [datetime.datetime(2016, 9, 14, 8, 0), 5822613],
#    [datetime.datetime(2016, 9, 14, 12, 0), 5822788],
#    [datetime.datetime(2016, 9, 14, 16, 0), 5823167],
#    [datetime.datetime(2016, 9, 14, 20, 0), 5824032],
#    [datetime.datetime(2016, 9, 15, 0, 0), 5824271],
#    [datetime.datetime(2016, 9, 15, 4, 0), 5824293],
#    [datetime.datetime(2016, 9, 15, 8, 0), 5824339],
#    [datetime.datetime(2016, 9, 15, 12, 0), 5824492],
#    [datetime.datetime(2016, 9, 15, 16, 0), 5824858],
#    [datetime.datetime(2016, 9, 15, 20, 0), 5825807],
#    [datetime.datetime(2016, 9, 16, 0, 0), 5826092],
#    [datetime.datetime(2016, 9, 16, 4, 0), 5826120],
#    [datetime.datetime(2016, 9, 16, 8, 0), 5826171],
#    [datetime.datetime(2016, 9, 16, 12, 0), 5826346],
#    [datetime.datetime(2016, 9, 16, 16, 0), 5826719],
#    [datetime.datetime(2016, 9, 16, 20, 0), 5827597],
#    [datetime.datetime(2016, 9, 17, 0, 0), 5827822],
#    [datetime.datetime(2016, 9, 17, 4, 0), 5827867],
#    [datetime.datetime(2016, 9, 17, 8, 0), 5827899],
#    [datetime.datetime(2016, 9, 17, 12, 0), 5828023],
#    [datetime.datetime(2016, 9, 17, 16, 0), 5828307],
#    [datetime.datetime(2016, 9, 17, 20, 0), 5828712],
#    [datetime.datetime(2016, 9, 18, 0, 0), 5828891],
#    [datetime.datetime(2016, 9, 18, 4, 0), 5828932],
#    [datetime.datetime(2016, 9, 18, 8, 0), 5828943],
#    [datetime.datetime(2016, 9, 18, 12, 0), 5829020],
#    [datetime.datetime(2016, 9, 18, 16, 0), 5829183],
#    [datetime.datetime(2016, 9, 18, 20, 0), 5829446],
#    [datetime.datetime(2016, 9, 19, 0, 0), 5829595],
#    [datetime.datetime(2016, 9, 19, 4, 0), 5829611],
#    [datetime.datetime(2016, 9, 19, 8, 0), 5829654],
#    [datetime.datetime(2016, 9, 19, 12, 0), 5829861],
#    [datetime.datetime(2016, 9, 19, 16, 0), 5830196],
#    [datetime.datetime(2016, 9, 19, 20, 0), 5831062],
#    [datetime.datetime(2016, 9, 20, 0, 0), 5831286],
#    [datetime.datetime(2016, 9, 20, 4, 0), 5831303],
#    [datetime.datetime(2016, 9, 20, 8, 0), 5831349],
#    [datetime.datetime(2016, 9, 20, 12, 0), 5831579],
#    [datetime.datetime(2016, 9, 20, 16, 0), 5831916],
#    [datetime.datetime(2016, 9, 20, 20, 0), 5832840],
#    [datetime.datetime(2016, 9, 21, 0, 0), 5833069],
#    [datetime.datetime(2016, 9, 21, 4, 0), 5833089],
#    [datetime.datetime(2016, 9, 21, 8, 0), 5833146],
#    [datetime.datetime(2016, 9, 21, 12, 0), 5833322],
#    [datetime.datetime(2016, 9, 21, 16, 0), 5833693],
#    [datetime.datetime(2016, 9, 21, 20, 0), 5834655],
#    [datetime.datetime(2016, 9, 22, 0, 0), 5834901],
#    [datetime.datetime(2016, 9, 22, 4, 0), 5834919],
#    [datetime.datetime(2016, 9, 22, 8, 0), 5834979],
#    [datetime.datetime(2016, 9, 22, 12, 0), 5835186],
#    [datetime.datetime(2016, 9, 22, 16, 0), 5835513],
#    [datetime.datetime(2016, 9, 22, 20, 0), 5836432],
#    [datetime.datetime(2016, 9, 23, 0, 0), 5836697],
#    [datetime.datetime(2016, 9, 23, 4, 0), 5836724],
#    [datetime.datetime(2016, 9, 23, 8, 0), 5836778],
#    [datetime.datetime(2016, 9, 23, 12, 0), 5836958],
#    [datetime.datetime(2016, 9, 23, 16, 0), 5837325],
#    [datetime.datetime(2016, 9, 23, 20, 0), 5838234],
#    [datetime.datetime(2016, 9, 24, 0, 0), 5838478],
#    [datetime.datetime(2016, 9, 24, 4, 0), 5838515],
#    [datetime.datetime(2016, 9, 24, 8, 0), 5838530],
#    [datetime.datetime(2016, 9, 24, 12, 0), 5838635],
#    [datetime.datetime(2016, 9, 24, 16, 0), 5838951],
#    [datetime.datetime(2016, 9, 24, 20, 0), 5839333],
#    [datetime.datetime(2016, 9, 25, 0, 0), 5839510],
#    [datetime.datetime(2016, 9, 25, 4, 0), 5839541],
#    [datetime.datetime(2016, 9, 25, 8, 0), 5839561],
#    [datetime.datetime(2016, 9, 25, 12, 0), 5839659],
#    [datetime.datetime(2016, 9, 25, 16, 0), 5839863],
#    [datetime.datetime(2016, 9, 25, 20, 0), 5840123],
#    [datetime.datetime(2016, 9, 26, 0, 0), 5840224],
#    [datetime.datetime(2016, 9, 26, 4, 0), 5840240],
#    [datetime.datetime(2016, 9, 26, 8, 0), 5840307],
#    [datetime.datetime(2016, 9, 26, 12, 0), 5840490],
#    [datetime.datetime(2016, 9, 26, 16, 0), 5840833],
#    [datetime.datetime(2016, 9, 26, 20, 0), 5841712],
#    [datetime.datetime(2016, 9, 27, 0, 0), 5841926],
#    [datetime.datetime(2016, 9, 27, 4, 0), 5841952],
#    [datetime.datetime(2016, 9, 27, 8, 0), 5842003],
#    [datetime.datetime(2016, 9, 27, 12, 0), 5842160],
#    [datetime.datetime(2016, 9, 27, 16, 0), 5842521],
#    [datetime.datetime(2016, 9, 27, 20, 0), 5843424],
#    [datetime.datetime(2016, 9, 28, 0, 0), 5843601],
#    [datetime.datetime(2016, 9, 28, 4, 0), 5843616],
#    [datetime.datetime(2016, 9, 28, 8, 0), 5843666],
#    [datetime.datetime(2016, 9, 28, 12, 0), 5843846],
#    [datetime.datetime(2016, 9, 28, 16, 0), 5844156],
#    [datetime.datetime(2016, 9, 28, 20, 0), 5845070],
#    [datetime.datetime(2016, 9, 29, 0, 0), 5845315],
#    [datetime.datetime(2016, 9, 29, 4, 0), 5845329],
#    [datetime.datetime(2016, 9, 29, 8, 0), 5845375],
#    [datetime.datetime(2016, 9, 29, 12, 0), 5845557],
#    [datetime.datetime(2016, 9, 29, 16, 0), 5845942],
#    [datetime.datetime(2016, 9, 29, 20, 0), 5846892],
#    [datetime.datetime(2016, 9, 30, 0, 0), 5847126],
#    [datetime.datetime(2016, 9, 30, 4, 0), 5847149],
#    [datetime.datetime(2016, 9, 30, 8, 0), 5847196],
#    [datetime.datetime(2016, 9, 30, 12, 0), 5847383],
#    [datetime.datetime(2016, 9, 30, 16, 0), 5847748],
#    [datetime.datetime(2016, 9, 30, 20, 0), 5848653],
#    [datetime.datetime(2016, 10, 1, 0, 0), 5848880],
#    [datetime.datetime(2016, 10, 1, 4, 0), 5848921],
#    [datetime.datetime(2016, 10, 1, 8, 0), 5848946],
#    [datetime.datetime(2016, 10, 1, 12, 0), 5849068],
#    [datetime.datetime(2016, 10, 1, 16, 0), 5849358],
#    [datetime.datetime(2016, 10, 1, 20, 0), 5849754],
#    [datetime.datetime(2016, 10, 2, 0, 0), 5849928],
#    [datetime.datetime(2016, 10, 2, 4, 0), 5849972],
#    [datetime.datetime(2016, 10, 2, 8, 0), 5849990],
#    [datetime.datetime(2016, 10, 2, 12, 0), 5850096],
#    [datetime.datetime(2016, 10, 2, 16, 0), 5850339],
#    [datetime.datetime(2016, 10, 2, 20, 0), 5850612],
#    [datetime.datetime(2016, 10, 3, 0, 0), 5850735],
#    [datetime.datetime(2016, 10, 3, 4, 0), 5850747],
#    [datetime.datetime(2016, 10, 3, 8, 0), 5850789],
#    [datetime.datetime(2016, 10, 3, 12, 0), 5850963],
#    [datetime.datetime(2016, 10, 3, 16, 0), 5851285],
#    [datetime.datetime(2016, 10, 3, 20, 0), 5852135],
#    [datetime.datetime(2016, 10, 4, 0, 0), 5852356],
#    [datetime.datetime(2016, 10, 4, 4, 0), 5852368],
#    [datetime.datetime(2016, 10, 4, 8, 0), 5852412],
#    [datetime.datetime(2016, 10, 4, 12, 0), 5852594],
#    [datetime.datetime(2016, 10, 4, 16, 0), 5852921],
#    [datetime.datetime(2016, 10, 4, 20, 0), 5853826],
#    [datetime.datetime(2016, 10, 5, 0, 0), 5854063],
#    [datetime.datetime(2016, 10, 5, 4, 0), 5854085],
#    [datetime.datetime(2016, 10, 5, 8, 0), 5854144],
#    [datetime.datetime(2016, 10, 5, 12, 0), 5854322],
#    [datetime.datetime(2016, 10, 5, 16, 0), 5854683],
#    [datetime.datetime(2016, 10, 5, 20, 0), 5855662],
#    [datetime.datetime(2016, 10, 6, 0, 0), 5855936],
#    [datetime.datetime(2016, 10, 6, 4, 0), 5855957],
#    [datetime.datetime(2016, 10, 6, 8, 0), 5856020],
#    [datetime.datetime(2016, 10, 6, 12, 0), 5856218],
#    [datetime.datetime(2016, 10, 6, 16, 0), 5856584],
#    [datetime.datetime(2016, 10, 6, 20, 0), 5857575],
#    [datetime.datetime(2016, 10, 7, 0, 0), 5857847],
#    [datetime.datetime(2016, 10, 7, 4, 0), 5857875],
#    [datetime.datetime(2016, 10, 7, 8, 0), 5857926],
#    [datetime.datetime(2016, 10, 7, 12, 0), 5858124],
#    [datetime.datetime(2016, 10, 7, 16, 0), 5858516],
#    [datetime.datetime(2016, 10, 7, 20, 0), 5859413],
#    [datetime.datetime(2016, 10, 8, 0, 0), 5859700],
#    [datetime.datetime(2016, 10, 8, 4, 0), 5859751],
#    [datetime.datetime(2016, 10, 8, 8, 0), 5859777],
#    [datetime.datetime(2016, 10, 8, 12, 0), 5859906],
#    [datetime.datetime(2016, 10, 8, 16, 0), 5860181],
#    [datetime.datetime(2016, 10, 8, 20, 0), 5860602],
#    [datetime.datetime(2016, 10, 9, 0, 0), 5860775],
#    [datetime.datetime(2016, 10, 9, 4, 0), 5860811],
#    [datetime.datetime(2016, 10, 9, 8, 0), 5860822],
#    [datetime.datetime(2016, 10, 9, 12, 0), 5860884],
#    [datetime.datetime(2016, 10, 9, 16, 0), 5861069],
#    [datetime.datetime(2016, 10, 9, 20, 0), 5861330],
#    [datetime.datetime(2016, 10, 10, 0, 0), 5861488],
#    [datetime.datetime(2016, 10, 10, 4, 0), 5861498],
#    [datetime.datetime(2016, 10, 10, 8, 0), 5861526],
#    [datetime.datetime(2016, 10, 10, 12, 0), 5861672],
#    [datetime.datetime(2016, 10, 10, 16, 0), 5861991],
#    [datetime.datetime(2016, 10, 10, 20, 0), 5862829],
#    [datetime.datetime(2016, 10, 11, 0, 0), 5863048],
#    [datetime.datetime(2016, 10, 11, 4, 0), 5863066],
#    [datetime.datetime(2016, 10, 11, 8, 0), 5863111],
#    [datetime.datetime(2016, 10, 11, 12, 0), 5863318],
#    [datetime.datetime(2016, 10, 11, 16, 0), 5863706],
#    [datetime.datetime(2016, 10, 11, 20, 0), 5864611],
#    [datetime.datetime(2016, 10, 12, 0, 0), 5864845],
#    [datetime.datetime(2016, 10, 12, 4, 0), 5864864],
#    [datetime.datetime(2016, 10, 12, 8, 0), 5864904],
#    [datetime.datetime(2016, 10, 12, 12, 0), 5865067],
#    [datetime.datetime(2016, 10, 12, 16, 0), 5865378],
#    [datetime.datetime(2016, 10, 12, 20, 0), 5866203],
#    [datetime.datetime(2016, 10, 13, 0, 0), 5866389],
#    [datetime.datetime(2016, 10, 13, 4, 0), 5866410],
#    [datetime.datetime(2016, 10, 13, 8, 0), 5866456],
#    [datetime.datetime(2016, 10, 13, 12, 0), 5866650],
#    [datetime.datetime(2016, 10, 13, 16, 0), 5867040],
#    [datetime.datetime(2016, 10, 13, 20, 0), 5867962],
#    [datetime.datetime(2016, 10, 14, 0, 0), 5868237],
#    [datetime.datetime(2016, 10, 14, 4, 0), 5868262],
#    [datetime.datetime(2016, 10, 14, 8, 0), 5868305],
#    [datetime.datetime(2016, 10, 14, 12, 0), 5868493],
#    [datetime.datetime(2016, 10, 14, 16, 0), 5868897],
#    [datetime.datetime(2016, 10, 14, 20, 0), 5869794],
#    [datetime.datetime(2016, 10, 15, 0, 0), 5870042],
#    [datetime.datetime(2016, 10, 15, 4, 0), 5870089],
#    [datetime.datetime(2016, 10, 15, 8, 0), 5870109],
#    [datetime.datetime(2016, 10, 15, 12, 0), 5870236],
#    [datetime.datetime(2016, 10, 15, 16, 0), 5870529],
#    [datetime.datetime(2016, 10, 15, 20, 0), 5870978],
#    [datetime.datetime(2016, 10, 16, 0, 0), 5871171],
#    [datetime.datetime(2016, 10, 16, 4, 0), 5871214],
#    [datetime.datetime(2016, 10, 16, 8, 0), 5871237],
#    [datetime.datetime(2016, 10, 16, 12, 0), 5871334],
#    [datetime.datetime(2016, 10, 16, 16, 0), 5871563],
#    [datetime.datetime(2016, 10, 16, 20, 0), 5871825],
#    [datetime.datetime(2016, 10, 17, 0, 0), 5871960],
#    [datetime.datetime(2016, 10, 17, 4, 0), 5871968],
#    [datetime.datetime(2016, 10, 17, 8, 0), 5872014],
#    [datetime.datetime(2016, 10, 17, 12, 0), 5872183],
#    [datetime.datetime(2016, 10, 17, 16, 0), 5872543],
#    [datetime.datetime(2016, 10, 17, 20, 0), 5873565],
#    [datetime.datetime(2016, 10, 18, 0, 0), 5873811],
#    [datetime.datetime(2016, 10, 18, 4, 0), 5873828],
#    [datetime.datetime(2016, 10, 18, 8, 0), 5873878],
#    [datetime.datetime(2016, 10, 18, 12, 0), 5874057],
#    [datetime.datetime(2016, 10, 18, 16, 0), 5874401],
#    [datetime.datetime(2016, 10, 18, 20, 0), 5875383],
#    [datetime.datetime(2016, 10, 19, 0, 0), 5875609],
#    [datetime.datetime(2016, 10, 19, 4, 0), 5875628],
#    [datetime.datetime(2016, 10, 19, 8, 0), 5875668],
#    [datetime.datetime(2016, 10, 19, 12, 0), 5875809],
#    [datetime.datetime(2016, 10, 19, 16, 0), 5876175],
#    [datetime.datetime(2016, 10, 19, 20, 0), 5877109],
#    [datetime.datetime(2016, 10, 20, 0, 0), 5877359],
#    [datetime.datetime(2016, 10, 20, 4, 0), 5877378],
#    [datetime.datetime(2016, 10, 20, 8, 0), 5877420],
#    [datetime.datetime(2016, 10, 20, 12, 0), 5877604],
#    [datetime.datetime(2016, 10, 20, 16, 0), 5877998],
#    [datetime.datetime(2016, 10, 20, 20, 0), 5878917],
#    [datetime.datetime(2016, 10, 21, 0, 0), 5879170],
#    [datetime.datetime(2016, 10, 21, 4, 0), 5879198],
#    [datetime.datetime(2016, 10, 21, 8, 0), 5879236],
#    [datetime.datetime(2016, 10, 21, 12, 0), 5879412],
#    [datetime.datetime(2016, 10, 21, 16, 0), 5879795],
#    [datetime.datetime(2016, 10, 21, 20, 0), 5880666],
#    [datetime.datetime(2016, 10, 22, 0, 0), 5880917],
#    [datetime.datetime(2016, 10, 22, 4, 0), 5880955],
#    [datetime.datetime(2016, 10, 22, 8, 0), 5880983],
#    [datetime.datetime(2016, 10, 22, 12, 0), 5881118],
#    [datetime.datetime(2016, 10, 22, 16, 0), 5881414],
#    [datetime.datetime(2016, 10, 22, 20, 0), 5881824],
#    [datetime.datetime(2016, 10, 23, 0, 0), 5882046],
#    [datetime.datetime(2016, 10, 23, 4, 0), 5882075],
#    [datetime.datetime(2016, 10, 23, 8, 0), 5882086],
#    [datetime.datetime(2016, 10, 23, 12, 0), 5882227],
#    [datetime.datetime(2016, 10, 23, 16, 0), 5882475],
#    [datetime.datetime(2016, 10, 23, 20, 0), 5882755],
#    [datetime.datetime(2016, 10, 24, 0, 0), 5882869],
#    [datetime.datetime(2016, 10, 24, 4, 0), 5882877],
#    [datetime.datetime(2016, 10, 24, 8, 0), 5882930],
#    [datetime.datetime(2016, 10, 24, 12, 0), 5883124],
#    [datetime.datetime(2016, 10, 24, 16, 0), 5883487],
#    [datetime.datetime(2016, 10, 24, 20, 0), 5884447],
#    [datetime.datetime(2016, 10, 25, 0, 0), 5884711],
#    [datetime.datetime(2016, 10, 25, 4, 0), 5884732],
#    [datetime.datetime(2016, 10, 25, 8, 0), 5884779],
#    [datetime.datetime(2016, 10, 25, 12, 0), 5884941],
#    [datetime.datetime(2016, 10, 25, 16, 0), 5885345],
#    [datetime.datetime(2016, 10, 25, 20, 0), 5886295],
#    [datetime.datetime(2016, 10, 26, 0, 0), 5886522],
#    [datetime.datetime(2016, 10, 26, 4, 0), 5886540],
#    [datetime.datetime(2016, 10, 26, 8, 0), 5886591],
#    [datetime.datetime(2016, 10, 26, 12, 0), 5886762],
#    [datetime.datetime(2016, 10, 26, 16, 0), 5887143],
#    [datetime.datetime(2016, 10, 26, 20, 0), 5888094],
#    [datetime.datetime(2016, 10, 27, 0, 0), 5888361],
#    [datetime.datetime(2016, 10, 27, 4, 0), 5888377],
#    [datetime.datetime(2016, 10, 27, 8, 0), 5888414],
#    [datetime.datetime(2016, 10, 27, 12, 0), 5888620],
#    [datetime.datetime(2016, 10, 27, 16, 0), 5888998],
#    [datetime.datetime(2016, 10, 27, 20, 0), 5889900],
#    [datetime.datetime(2016, 10, 28, 0, 0), 5890149],
#    [datetime.datetime(2016, 10, 28, 4, 0), 5890170],
#    [datetime.datetime(2016, 10, 28, 8, 0), 5890215],
#    [datetime.datetime(2016, 10, 28, 12, 0), 5890425],
#    [datetime.datetime(2016, 10, 28, 16, 0), 5890849],
#    [datetime.datetime(2016, 10, 28, 20, 0), 5891775]])]

# %% [markdown]
# ## 6. Summarize By Turnstile By Day
# ___

# %% [markdown]
# Great - we now have a single dictionary with a turnstile ID (Key) and the timestamped cumulative passenger entry data (value) per hour.
#
# Now we want to summarize this hourly data into a daily number.  We can do that using our calculate_daily_summary below.

# %%
def validate_daily_total(total):
    """
        Takes a total number of passengers that has visited a turnstile over the 
        period of 1 day and validates that its within a predefined limit.  
        For now, the limit is to ensure the total is greater than 0, and less than 10,000 passengers
    """
    if total == None:
        return True
    else:
        return 15000 > total >= 0

# %%
from itertools import groupby
from collections import defaultdict

def calculate_daily_summary(data, turnstile_id):
    """
        Takes an array of hourly turnstile entries spread across multiple days and summarizes
        the data at a daily level. 
    """

    # create a varaible to hold our summary per day
    turnstile_daily_summary = []
    error = ''
    
    # create a variable to store the previous day's passenger count
    passenger_count_prevday = None
    
    # group the turnstile entries by date
    for current_date, daily_entries in groupby(data, lambda x: x[0].date()):
        
        # find the maximum for the day
        passenger_count_curday = max([count for time, count in daily_entries])

        # calculate total for the day
        if passenger_count_prevday == None:
            daily_total = None;
        else:
            daily_total = passenger_count_curday - passenger_count_prevday
            
        # check to ensure date count isn't crazy insane
        if validate_daily_total(daily_total):
            turnstile_daily_summary.append([current_date, daily_total])
        else:
            #print('Warning: Date total appears to be incorrect for {} total: {}'.format(current_date, daily_total))
            control, remote, unit, station, line, division = turnstile_id
            error = '{} {}'.format(station, line)
            turnstile_daily_summary.append([current_date, None])
        
        # update the date counter
        passenger_count_prevday = passenger_count_curday
    
    return turnstile_daily_summary, error

# %%
# create our new summary variable
timestamped_per_turnstile_per_day = defaultdict(list)

# we also want to track any stations that may have an error
errored_entries = set()

# loop through the dictionary and summarize
for i, (turnstile, hourly_entries) in enumerate(timestamped_per_turnstile.items()):
    #print('===   Processing {}   ==='.format(turnstile))
    timestamped_per_turnstile_per_day[turnstile], error = calculate_daily_summary(hourly_entries, turnstile)
    
    # if we find an error - record the station that occurred
    if error:
        errored_entries.add(error)

# %%
# have a look at the number of stations that potentially have errors
print(len(errored_entries))
# Out:
# 129

# %%
# Take a sneak peak at our data so far
sample_data = list(timestamped_per_turnstile_per_day.items())[:1]
#print(sample_data)

# %% [markdown]
# Based on the above dataset, we can see that a large number of our stations have potential erros in their turnstiles.  Based on the large majority of turnstiles having errors, we will proceed without removing any.

# %% [markdown]
# ## 7. Summarize Per Station By Day

# %% [markdown]
# We now have a daily summary for the number of passengers that visit each turnstile in a station.  A station may have many turnstiles - in order for us to be able to do an analysis, we want to know how many passengers pass through a station.  Let's get the daily summary per station using the group_by_station function below.
#
# *Note: We are grouping by station & line because it is possible to have the same station name on multiple lines*

# %%
def get_station_name(turnstile_data):
    """
        Given turnstile data in the form (turnstile, timeseries), 
        unpack the data and return the identifier defined by station, line
    """
    # unpack the data
    turnstile, timeseries = turnstile_data
    control_area, unit, device_id, station, line, div = turnstile

    return (tuple([station, line, div]))

# %%
from collections import Counter
import operator

def group_by_station(data):
    """
        Given data grouped by turnstile, summarize daily passenger counts
        by station.
    """

    mta_data_by_station = {}

    # sort our dictionary first - this ensures we groupby correctly
    data_sorted = sorted(data.items(), key=operator.itemgetter(0))
    
    # loop through data by station
    for station, data in groupby(data_sorted, get_station_name):   
            
        # initalize counter
        daily_counter = Counter()
        
        # loop through each turnstile in the station
        for turnstile, timeseries in data:
                    
            # Unpack the timeseries - begin to summarize by station
            for datestamp, passenger_count in timeseries:           
                
                # ensure we only add integer values
                if passenger_count is not None:
                    daily_counter[datestamp] += passenger_count
                           
        # store the count per station
        mta_data_by_station[station] = sorted(daily_counter.items())
            
    return mta_data_by_station

# %%
timestamped_per_station_per_day = group_by_station(timestamped_per_turnstile_per_day)

# %%
# Print out all station names
#for st, val in timestamped_per_station_per_day.items():
#    station, line, division = st
#    print('{},{},{}'.format(station, line, division))

# %% [markdown]
# ## 8. Data Export

# %% [markdown]
# We now have cleaned data to a point where we have a timestamp, station name, total ridership.  Let's export this to a csv so that it can be consumed into a dataframe.

# %%
import csv

# write to file named nyc_mta_data_cleaned
with open('./data/nyc_mta_data_cleaned.csv', 'w') as f:
    writer = csv.writer(f)
    
    # add header row
    row = []
    row.append('date')
    row.append('station')
    row.append('line')
    row.append('division')
    row.append('daily_ridership')
    writer.writerow(row)

    # loop through each record
    for station, time_entry in timestamped_per_station_per_day.items():
        st, line, div = station

        # add the details of each record to the csv
        for date, ridership in time_entry:
            row = []
            row.append(date)
            row.append(st)
            row.append(line)
            row.append(div)
            row.append(ridership)

            writer.writerow(row)
